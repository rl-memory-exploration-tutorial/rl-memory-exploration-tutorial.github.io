# %% [markdown]
# # **<center>Notebook: Memory for Surprise-driven Exploration (Atari Ver.)</center>**

# %% [markdown]
# **Reference:**
# 1. Burda, Y., Edwards, H., Storkey, A., & Klimov, O. (2018). Exploration by random network distillation. arXiv preprint arXiv:1810.12894.
# 2. Pathak, D., Agrawal, P., Efros, A. A., & Darrell, T. (2017, July). Curiosity-driven exploration by self-supervised prediction. In International conference on machine learning (pp. 2778-2787). PMLR.
# 3. Huang, S., Dossa, R. F. J., Ye, C., Braga, J., Chakraborty, D., Mehta, K., & AraÃšjo, J. G. (2022). Cleanrl: High-quality single-file implementations of deep reinforcement learning algorithms. Journal of Machine Learning Research, 23(274), 1-18.
# 4. Brockman, G., Cheung, V., Pettersson, L., Schneider, J., Schulman, J., Tang, J., & Zaremba, W. (2016). Openai gym. arXiv preprint arXiv:1606.01540.

# %% [markdown]
# ## **1. Setting up the libraries**

# %%
# Run these commands from the terminal to install related libraries and set up the working environment
# pip install gym # Install the gym library with RL environments
# pip install envpool
# pip install torch

# %%
import os, random, time
from collections import deque
from dataclasses import dataclass

import pandas as pd
import gym
import numpy as np
import torch
import envpool

import torch.nn as nn
from torch.nn import init
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter
from gym.wrappers.normalize import RunningMeanStd
import matplotlib.pyplot as plt

# %%
envpool.list_all_envs()
# Out:
# ['Adventure-v5',
#  'AirRaid-v5',
#  'Alien-v5',
#  'Amidar-v5',
#  'Assault-v5',
#  'Asterix-v5',
#  'Asteroids-v5',
#  'Atlantis-v5',
#  'Atlantis2-v5',
#  'Backgammon-v5',
#  'BankHeist-v5',
#  'BasicMath-v5',
#  'BattleZone-v5',
#  'BeamRider-v5',
#  'Berzerk-v5',
#  'Blackjack-v5',
#  'Bowling-v5',
#  'Boxing-v5',
#  'Breakout-v5',
#  'Carnival-v5',
#  'Casino-v5',
#  'Centipede-v5',
#  'ChopperCommand-v5',
#  'CrazyClimber-v5',
#  'Crossbow-v5',
#  'Darkchambers-v5',
#  'Defender-v5',
#  'DemonAttack-v5',
#  'DonkeyKong-v5',
#  'DoubleDunk-v5',
#  'Earthworld-v5',
#  'ElevatorAction-v5',
#  'Enduro-v5',
#  'Entombed-v5',
#  'Et-v5',
#  'FishingDerby-v5',
#  'FlagCapture-v5',
#  'Freeway-v5',
#  'Frogger-v5',
#  'Frostbite-v5',
#  'Galaxian-v5',
#  'Gopher-v5',
#  'Gravitar-v5',
#  'Hangman-v5',
#  'HauntedHouse-v5',
#  'Hero-v5',
#  'HumanCannonball-v5',
#  'IceHockey-v5',
#  'Jamesbond-v5',
#  'JourneyEscape-v5',
#  'Kaboom-v5',
#  'Kangaroo-v5',
#  'KeystoneKapers-v5',
#  'KingKong-v5',
#  'Klax-v5',
#  'Koolaid-v5',
#  'Krull-v5',
#  'KungFuMaster-v5',
#  'LaserGates-v5',
#  'LostLuggage-v5',
#  'MarioBros-v5',
#  'MiniatureGolf-v5',
#  'MontezumaRevenge-v5',
#  'MrDo-v5',
#  'MsPacman-v5',
#  'NameThisGame-v5',
#  'Othello-v5',
#  'Pacman-v5',
#  'Phoenix-v5',
#  'Pitfall-v5',
#  'Pitfall2-v5',
#  'Pong-v5',
#  'Pooyan-v5',
#  'PrivateEye-v5',
#  'Qbert-v5',
#  'Riverraid-v5',
#  'RoadRunner-v5',
#  'Robotank-v5',
#  'Seaquest-v5',
#  'SirLancelot-v5',
#  'Skiing-v5',
#  'Solaris-v5',
#  'SpaceInvaders-v5',
#  'SpaceWar-v5',
#  'StarGunner-v5',
#  'Superman-v5',
#  'Surround-v5',
#  'Tennis-v5',
#  'Tetris-v5',
#  'TicTacToe3d-v5',
#  'TimePilot-v5',
#  'Trondead-v5',
#  'Turmoil-v5',
#  'Tutankham-v5',
#  'UpNDown-v5',
#  'Venture-v5',
#  'VideoCheckers-v5',
#  'VideoChess-v5',
#  'VideoCube-v5',
#  'VideoPinball-v5',
#  'WizardOfWor-v5',
#  'WordZapper-v5',
#  'YarsRevenge-v5',
#  'Zaxxon-v5',
#  'CarRacing-v2',
#  'BipedalWalker-v3',
#  'BipedalWalkerHardcore-v3',
#  'LunarLander-v2',
#  'LunarLanderContinuous-v2',
#  'CartPole-v0',
#  'CartPole-v1',
#  'Pendulum-v0',
#  'Pendulum-v1',
#  'MountainCar-v0',
#  'MountainCarContinuous-v0',
#  'Acrobot-v1',
#  'AcrobotSwingup-v1',
#  'AcrobotSwingupSparse-v1',
#  'BallInCupCatch-v1',
#  'CartpoleBalance-v1',
#  'CartpoleBalanceSparse-v1',
#  'CartpoleSwingup-v1',
#  'CartpoleSwingupSparse-v1',
#  'CartpoleThreePoles-v1',
#  'CartpoleTwoPoles-v1',
#  'CheetahRun-v1',
#  'FingerSpin-v1',
#  'FingerTurnEasy-v1',
#  'FingerTurnHard-v1',
#  'FishSwim-v1',
#  'FishUpright-v1',
#  'HopperHop-v1',
#  'HopperStand-v1',
#  'HumanoidRun-v1',
#  'HumanoidRunPureState-v1',
#  'HumanoidStand-v1',
#  'HumanoidWalk-v1',
#  'HumanoidCMURun-v1',
#  'HumanoidCMUStand-v1',
#  'ManipulatorBringBall-v1',
#  'ManipulatorBringPeg-v1',
#  'ManipulatorInsertBall-v1',
#  'ManipulatorInsertPeg-v1',
#  'PendulumSwingup-v1',
#  'PointMassEasy-v1',
#  'PointMassHard-v1',
#  'ReacherEasy-v1',
#  'ReacherHard-v1',
#  'SwimmerSwimmer6-v1',
#  'SwimmerSwimmer15-v1',
#  'WalkerRun-v1',
#  'WalkerStand-v1',
#  'WalkerWalk-v1',
#  'Ant-v3',
#  'Ant-v4',
#  'HalfCheetah-v3',
#  'HalfCheetah-v4',
#  'Hopper-v3',
#  'Hopper-v4',
#  'Humanoid-v3',
#  'Humanoid-v4',
#  'HumanoidStandup-v2',
#  'HumanoidStandup-v4',
#  'InvertedDoublePendulum-v2',
#  'InvertedDoublePendulum-v4',
#  'InvertedPendulum-v2',
#  'InvertedPendulum-v4',
#  'Pusher-v2',
#  'Pusher-v4',
#  'Reacher-v2',
#  'Reacher-v4',
#  'Swimmer-v3',
#  'Swimmer-v4',
#  'Walker2d-v3',
#  'Walker2d-v4',
#  'BigfishEasy-v0',
#  'BigfishHard-v0',
#  'BossfightEasy-v0',
#  'BossfightHard-v0',
#  'CaveflyerEasy-v0',
#  'CaveflyerHard-v0',
#  'CaveflyerMemory-v0',
#  'ChaserEasy-v0',
#  'ChaserHard-v0',
#  'ChaserExtreme-v0',
#  'ClimberEasy-v0',
#  'ClimberHard-v0',
#  'CoinrunEasy-v0',
#  'CoinrunHard-v0',
#  'DodgeballEasy-v0',
#  'DodgeballHard-v0',
#  'DodgeballExtreme-v0',
#  'DodgeballMemory-v0',
#  'FruitbotEasy-v0',
#  'FruitbotHard-v0',
#  'HeistEasy-v0',
#  'HeistHard-v0',
#  'HeistMemory-v0',
#  'JumperEasy-v0',
#  'JumperHard-v0',
#  'JumperMemory-v0',
#  'LeaperEasy-v0',
#  'LeaperHard-v0',
#  'LeaperExtreme-v0',
#  'MazeEasy-v0',
#  'MazeHard-v0',
#  'MazeMemory-v0',
#  'MinerEasy-v0',
#  'MinerHard-v0',
#  'MinerMemory-v0',
#  'NinjaEasy-v0',
#  'NinjaHard-v0',
#  'PlunderEasy-v0',
#  'PlunderHard-v0',
#  'StarpilotEasy-v0',
#  'StarpilotHard-v0',
#  'StarpilotExtreme-v0',
#  'Catch-v0',
#  'FrozenLake-v1',
#  'FrozenLake8x8-v1',
#  'Taxi-v3',
#  'NChain-v0',
#  'CliffWalking-v0',
#  'Blackjack-v1',
#  'D1Basic-v1',
#  'D2Navigation-v1',
#  'D3Battle-v1',
#  'D4Battle2-v1',
#  'Basic-v1',
#  'Cig-v1',
#  'DeadlyCorridor-v1',
#  'Deathmatch-v1',
#  'DefendTheCenter-v1',
#  'DefendTheLine-v1',
#  'HealthGathering-v1',
#  'HealthGatheringSupreme-v1',
#  'MultiDuel-v1',
#  'MyWayHome-v1',
#  'PredictPosition-v1',
#  'RocketBasic-v1',
#  'SimplerBasic-v1',
#  'TakeCover-v1',
#  'VizdoomCustom-v1']

# %% [markdown]
# ## **2. Simple PPO**

# %% [markdown]
# ### **2.1 Parameters**

# %%
params = {'env_id': "Breakout-v5",
          'exp_name': "RND",
          'torch_deterministic': True,
          'cuda': True,
          'seed': 1,
          # Training parameters
          'num_envs': 8,                                        # number of multi-environments
          'num_steps': 128,                                     # number of steps running in each environments per rollout
          'num_minibatches': 4,                                 # number of minibatches
          'total_timesteps': 6000000,                            # total training timesteps
          'learning_rate': 1e-4,                                # learning_rate
          'anneal_lr': True,                                    # reducing learning rate during learning
          'num_iterations_obs_norm_init': 50,
          'gamma': 0.999,
          'int_gamma': 0.99,
          'gae_lambda': 0.95,
          'int_coef': 1.0,
          'ext_coef': 2.0,
          'update_epochs': 4,
          'update_proportion': 0.25,
          'clip_coef': 0.1,
          'norm_adv': True,
          'clip_vloss': True,
          'ent_coef': 0.001,
          'vf_coef': 0.5,
          'max_grad_norm': 0.5,
          'target_kl': None}

device = torch.device("cuda" if torch.cuda.is_available() and params["cuda"] else "cpu")

# Set seed.
random.seed(params["seed"])                                                 
np.random.seed(params["seed"])
torch.manual_seed(params["seed"])
torch.backends.cudnn.deterministic = params["torch_deterministic"]

# %% [markdown]
# ### **2.1 Models**

# %% [markdown]
# #### **2.2.1 Utils**

# %%
class RecordEpisodeStatistics(gym.Wrapper):
    def __init__(self, env, deque_size=100):
        super().__init__(env)
        self.num_envs = getattr(env, "num_envs", 1)
        self.episode_returns = None
        self.episode_lengths = None

    def reset(self, **kwargs):
        observations = super().reset(**kwargs)
        self.episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        self.lives = np.zeros(self.num_envs, dtype=np.int32)
        self.returned_episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.returned_episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        return observations

    def step(self, action):
        observations, rewards, dones, _, infos = super().step(action)
        self.episode_returns += infos["reward"]
        self.episode_lengths += 1
        self.returned_episode_returns[:] = self.episode_returns
        self.returned_episode_lengths[:] = self.episode_lengths
        self.episode_returns *= 1 - infos["terminated"]
        self.episode_lengths *= 1 - infos["terminated"]
        infos["r"] = self.returned_episode_returns
        infos["l"] = self.returned_episode_lengths
        return (observations, rewards, dones, infos)

# %%
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)                # Initialize layer weights according to orthogonal method.
    torch.nn.init.constant_(layer.bias, bias_const)             # Set the bias of the layer.
    return layer

# %% [markdown]
# #### **2.2.2 PPO Agent**

# %%
class PPOAgent(nn.Module):
    def __init__(self, envs, use_int_rews=False):
        super().__init__()
        self.use_int_rews = use_int_rews

        self.network = nn.Sequential(
            layer_init(nn.Conv2d(4, 32, 8, stride=4)),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 4, stride=2)),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(64 * 7 * 7, 256)),
            nn.ReLU(),
            layer_init(nn.Linear(256, 448)),
            nn.ReLU(),
        )

        self.extra_layer = nn.Sequential(layer_init(nn.Linear(448, 448), std=0.1), nn.ReLU())

        self.actor = nn.Sequential(
            layer_init(nn.Linear(448, 448), std=0.01),
            nn.ReLU(),
            layer_init(nn.Linear(448, envs.single_action_space.n), std=0.01),
        )
        
        self.critic_ext = layer_init(nn.Linear(448, 1), std=0.01)
        self.critic_int = layer_init(nn.Linear(448, 1), std=0.01)

    def get_action_and_value(self, x, action=None):
        hidden = self.network(x / 255.0)
        logits = self.actor(hidden)
        probs = Categorical(logits=logits)
        features = self.extra_layer(hidden)
        if action is None:
            action = probs.sample()
        if self.use_int_rews:                                           # If intrinsic reward is used
            return (action, probs.log_prob(action), probs.entropy(), self.critic_ext(features + hidden), self.critic_int(features + hidden),)
        else:                                                           # If intrinsic reward is not used
            return (action, probs.log_prob(action), probs.entropy(), self.critic_ext(features + hidden),)

    def get_value(self, x):
        hidden = self.network(x / 255.0)
        features = self.extra_layer(hidden)
        if self.use_int_rews:                                           # If intrinsic reward is used
            return self.critic_ext(features + hidden), self.critic_int(features + hidden)
        else:                                                           # If intrinsic reward is not used
            return self.critic_ext(features + hidden)

# %% [markdown]
# #### **2.2.3 Main Training Loop**

# %%
env_id = params["env_id"]
exp_name = params["exp_name"]
seed = params["seed"]
run_name = f"{env_id}__{exp_name}__{seed}__{int(time.time())}"

envs = envpool.make(
    params["env_id"],
    env_type="gym",
    num_envs=params["num_envs"],
    episodic_life=True,
    reward_clip=True,
    seed=params["seed"],
    repeat_action_probability=0.25,
)

envs.num_envs = params["num_envs"]
envs.single_action_space = envs.action_space
print(f"The action space of the environment is {envs.single_action_space}")
envs.single_observation_space = envs.observation_space
print(f"The observation space of the environment is {envs.single_observation_space}")

envs = RecordEpisodeStatistics(envs)
assert isinstance(envs.action_space, gym.spaces.Discrete), "only discrete action space is supported"
# Out:
# The action space of the environment is Discrete(4)
# The observation space of the environment is Box(0, 255, (4, 84, 84), uint8)

# %%
# Set up agent and model
Agent = PPOAgent(envs, use_int_rews=False).to(device)
optimizer = optim.Adam(
    Agent.parameters(),
    lr=params["learning_rate"],
    eps=1e-5,
)

# %%
obs = torch.zeros((params["num_steps"], params["num_envs"]) + envs.single_observation_space.shape).to(device)  
actions = torch.zeros((params["num_steps"], params["num_envs"]) + envs.single_action_space.shape).to(device)   
logprobs = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
rewards = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
dones = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
values = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
avg_returns = deque(maxlen=20)

batch_size = int(params["num_envs"] * params["num_steps"])                
minibatch_size = int(batch_size // params["num_minibatches"])
num_iterations = params["total_timesteps"] // batch_size

# %%
global_step = 0
start_time = time.time()
next_obs = torch.Tensor(envs.reset()[0]).to(device)
next_done = torch.zeros(params["num_envs"]).to(device)
results_simple_PPO = {"global_step":[],
                      "return_value":[]}
tracking_global_step = 0

for iteration in range(1, num_iterations+1):
    if params["anneal_lr"]:
        updated_lr = (1.0 - (iteration - 1.0) / num_iterations) * params["learning_rate"]
        optimizer.param_groups[0]["lr"] = updated_lr
    
    for step in range(0, params["num_steps"]):
        global_step += 1 * params["num_envs"]
        obs[step] = next_obs
        dones[step] = next_done 

        with torch.no_grad():
            action, logprob, _, value = Agent.get_action_and_value(obs[step])
            values[step] = value.flatten()
        actions[step] = action
        logprobs[step] = logprob

        next_obs, reward, done, info = envs.step(action.cpu().numpy())
        rewards[step] = torch.tensor(reward).to(device).view(-1)
        next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

        for idx, d in enumerate(done):
            # If done and no more live -> Get return
            if d and info["lives"][idx] == 0:
                avg_returns.append(info["r"][idx])
                epi_ret = np.average(avg_returns)
                print(
                    f"global_step={global_step}, episodic_return={info['r'][idx]}"
                )
                if global_step - tracking_global_step > 10000:
                    results_simple_PPO["global_step"].append(global_step)
                    results_simple_PPO["return_value"].append(info['r'][idx])
                    tracking_global_step = global_step

    # bootstrap value if not done
    with torch.no_grad():
        next_value = Agent.get_value(next_obs).reshape(1, -1)
        advantages = torch.zeros_like(rewards).to(device)
        lastgaelam = 0
        for t in reversed(range(params["num_steps"])):
            if t == params["num_steps"] - 1:
                nextnonterminal = 1.0 - next_done
                nextvalues = next_value
            else:
                nextnonterminal = 1.0 - dones[t + 1]
                nextvalues = values[t + 1]
            delta = rewards[t] + params["gamma"] * nextvalues * nextnonterminal - values[t]
            advantages[t] = lastgaelam = delta + params["gamma"] * params["gae_lambda"] * nextnonterminal * lastgaelam
        returns = advantages + values

    # flatten the batch
    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
    b_advantages = advantages.reshape(-1)
    b_returns = returns.reshape(-1)
    b_values = values.reshape(-1)

    # Optimizing the policy and value network
    b_inds = np.arange(batch_size)
    clipfracs = []
    for epoch in range(params["update_epochs"]):
        np.random.shuffle(b_inds)
        for start in range(0, batch_size, minibatch_size):
            end = start + minibatch_size
            mb_inds = b_inds[start:end]

            _, newlogprob, entropy, newvalue = Agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            with torch.no_grad():
                # calculate approx_kl http://joschu.net/blog/kl-approx.html
                old_approx_kl = (-logratio).mean()
                approx_kl = ((ratio - 1) - logratio).mean()
                clipfracs += [((ratio - 1.0).abs() > params["clip_coef"]).float().mean().item()]

            mb_advantages = b_advantages[mb_inds]
            if params["norm_adv"]:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            # Policy loss
            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - params["clip_coef"], 1 + params["clip_coef"])
            pg_loss = torch.max(pg_loss1, pg_loss2).mean()

            # Value loss
            newvalue = newvalue.view(-1)
            if params["clip_vloss"]:
                value_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                v_clipped = b_values[mb_inds] + torch.clamp(
                    newvalue - b_values[mb_inds],
                    -params["clip_coef"],
                    params["clip_coef"],
                )
                value_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                value_loss_max = torch.max(value_loss_unclipped, value_loss_clipped)
                value_loss = 0.5 * value_loss_max.mean()
            else:
                value_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

            entropy_loss = entropy.mean()
            loss = pg_loss - params["ent_coef"] * entropy_loss + value_loss * params["vf_coef"]

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(Agent.parameters(), params["max_grad_norm"])
            optimizer.step()

        if params["target_kl"] is not None and approx_kl > params["target_kl"]:
            break

    y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
    var_y = np.var(y_true)
    explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

    print("SPS:", int(global_step / (time.time() - start_time)))
# Out:
# global_step=944, episodic_return=0.0
# global_step=976, episodic_return=0.0
# SPS: 187
# global_step=1160, episodic_return=0.0
# global_step=1352, episodic_return=1.0
# global_step=1664, episodic_return=2.0
# global_step=1752, episodic_return=2.0
# global_step=1984, episodic_return=3.0
# SPS: 284
# global_step=2088, episodic_return=3.0
# global_step=2376, episodic_return=1.0
# global_step=2640, episodic_return=2.0
# global_step=2672, episodic_return=0.0
# global_step=3056, episodic_return=1.0
# SPS: 347
# global_step=3088, episodic_return=0.0
# global_step=3368, episodic_return=0.0
# global_step=3480, episodic_return=3.0
# global_step=3512, episodic_return=7.0
# global_step=3680, episodic_return=2.0
# global_step=3680, episodic_return=0.0
# global_step=4064, episodic_return=0.0
# SPS: 389
# global_step=4112, episodic_return=1.0
# global_step=4704, episodic_return=0.0
# global_step=4712, episodic_return=1.0
# global_step=4776, episodic_return=1.0
# global_step=4880, episodic_return=2.0
# global_step=5064, episodic_return=1.0
# SPS: 421
# global_step=5144, episodic_return=0.0
# global_step=5728, episodic_return=0.0
# global_step=5776, episodic_return=2.0
# global_step=5896, episodic_return=1.0
# global_step=5896, episodic_return=4.0
# global_step=6064, episodic_return=1.0
# global_step=6136, episodic_return=0.0
# SPS: 444
# global_step=6160, episodic_return=1.0
# global_step=6728, episodic_return=0.0
# global_step=92600, episodic_return=1.0
# global_step=92720, episodic_return=0.0
# global_step=92840, episodic_return=0.0
# global_step=93176, episodic_return=0.0
# SPS: 590
# global_step=93232, episodic_return=1.0
# global_step=93240, episodic_return=0.0
# global_step=93544, episodic_return=2.0
# global_step=93744, episodic_return=0.0
# global_step=93760, episodic_return=1.0
# global_step=93840, episodic_return=0.0
# global_step=94024, episodic_return=1.0
# SPS: 590
# global_step=94264, episodic_return=0.0
# global_step=94448, episodic_return=1.0
# global_step=94552, episodic_return=0.0
# global_step=94872, episodic_return=0.0
# global_step=95088, episodic_return=0.0
# SPS: 590
# global_step=95496, episodic_return=0.0
# global_step=95504, episodic_return=1.0
# global_step=95624, episodic_return=5.0
# global_step=95640, episodic_return=0.0
# global_step=95720, episodic_return=2.0
# global_step=95832, episodic_return=3.0
# global_step=96144, episodic_return=1.0
# SPS: 590
# global_step=96376, episodic_return=1.0
# global_step=96520, episodic_return=0.0
# global_step=97016, episodic_return=1.0
# global_step=97144, episodic_return=1.0
# global_step=97208, episodic_return=2.0
# global_step=97248, episodic_return=2.0
# SPS: 590
# global_step=98048, episodic_return=1.0
# global_step=98088, episodic_return=2.0
# global_step=98144, episodic_return=0.0
# global_step=98248, episodic_return=0.0
# SPS: 590
# global_step=98440, episodic_return=1.0
# global_step=98496, episodic_return=6.0
# global_step=98512, episodic_return=1.0
# global_step=98776, episodic_return=4.0
# global_step=99072, episodic_return=0.0
# SPS: 590
# global_step=99552, episodic_return=0.0
# global_step=99552, episodic_return=1.0
# global_step=99840, episodic_return=2.0
# global_step=99976, episodic_return=2.0
# global_step=100144, episodic_return=3.0
# global_step=100168, episodic_return=0.0
# SPS: 590
# global_step=100568, episodic_return=3.0
# global_step=100976, episodic_return=4.0
# global_step=101024, episodic_return=0.0
# global_step=101040, episodic_return=1.0
# global_step=101048, episodic_return=1.0
# global_step=101168, episodic_return=2.0
# global_step=101240, episodic_return=0.0
# SPS: 590
# global_step=101584, episodic_return=2.0
# global_step=101912, episodic_return=1.0
# global_step=102024, episodic_return=0.0
# global_step=102072, episodic_return=0.0
# global_step=102208, episodic_return=1.0
# global_step=102272, episodic_return=0.0
# global_step=102280, episodic_return=1.0
# global_step=102392, episodic_return=0.0
# SPS: 590
# global_step=102584, episodic_return=0.0
# global_step=103248, episodic_return=1.0
# global_step=103272, episodic_return=0.0
# global_step=103288, episodic_return=1.0
# global_step=103296, episodic_return=0.0
# global_step=103344, episodic_return=0.0
# SPS: 591
# global_step=103640, episodic_return=2.0
# global_step=103648, episodic_return=1.0
# SPS: 589
# global_step=104464, episodic_return=3.0
# global_step=104504, episodic_return=1.0
# global_step=104712, episodic_return=0.0
# global_step=104744, episodic_return=1.0
# global_step=104784, episodic_return=1.0
# global_step=105104, episodic_return=3.0
# global_step=105168, episodic_return=1.0
# global_step=105408, episodic_return=3.0
# global_step=105464, episodic_return=0.0
# SPS: 589
# global_step=105784, episodic_return=1.0
# global_step=105800, episodic_return=0.0
# global_step=106096, episodic_return=1.0
# global_step=106352, episodic_return=1.0
# global_step=195464, episodic_return=1.0
# global_step=195520, episodic_return=0.0
# SPS: 599
# global_step=195616, episodic_return=2.0
# global_step=196576, episodic_return=3.0
# SPS: 599
# global_step=196720, episodic_return=6.0
# global_step=197008, episodic_return=2.0
# global_step=197104, episodic_return=2.0
# global_step=197120, episodic_return=2.0
# global_step=197496, episodic_return=3.0
# SPS: 599
# global_step=197776, episodic_return=1.0
# global_step=197816, episodic_return=4.0
# global_step=198064, episodic_return=5.0
# global_step=198360, episodic_return=1.0
# SPS: 599
# global_step=199392, episodic_return=4.0
# global_step=199552, episodic_return=2.0
# SPS: 599
# global_step=199712, episodic_return=5.0
# global_step=199720, episodic_return=2.0
# global_step=199800, episodic_return=4.0
# global_step=199928, episodic_return=6.0
# global_step=200072, episodic_return=4.0
# SPS: 599
# global_step=200720, episodic_return=4.0
# global_step=200728, episodic_return=1.0
# global_step=201128, episodic_return=1.0
# global_step=201200, episodic_return=2.0
# global_step=201528, episodic_return=1.0
# global_step=201672, episodic_return=3.0
# SPS: 599
# global_step=201768, episodic_return=0.0
# global_step=202440, episodic_return=5.0
# global_step=202560, episodic_return=3.0
# SPS: 600
# global_step=202976, episodic_return=6.0
# global_step=203200, episodic_return=2.0
# global_step=203336, episodic_return=3.0
# global_step=203384, episodic_return=3.0
# SPS: 600
# global_step=204016, episodic_return=2.0
# global_step=204480, episodic_return=8.0
# global_step=204504, episodic_return=5.0
# SPS: 600
# global_step=205016, episodic_return=3.0
# global_step=205048, episodic_return=5.0
# global_step=205072, episodic_return=3.0
# global_step=205392, episodic_return=1.0
# global_step=205680, episodic_return=4.0
# SPS: 600
# global_step=206032, episodic_return=5.0
# global_step=206304, episodic_return=1.0
# global_step=206448, episodic_return=3.0
# global_step=206528, episodic_return=3.0
# global_step=206616, episodic_return=2.0
# global_step=206840, episodic_return=2.0
# SPS: 600
# SPS: 600
# global_step=207888, episodic_return=0.0
# global_step=207976, episodic_return=5.0
# global_step=208104, episodic_return=3.0
# global_step=208304, episodic_return=2.0
# global_step=208392, episodic_return=6.0
# global_step=208424, episodic_return=4.0
# global_step=208608, episodic_return=3.0
# SPS: 600
# global_step=209200, episodic_return=5.0
# global_step=209408, episodic_return=0.0
# global_step=209720, episodic_return=2.0
# SPS: 600
# global_step=210080, episodic_return=2.0
# global_step=210720, episodic_return=5.0
# global_step=210840, episodic_return=1.0
# global_step=210904, episodic_return=5.0
# SPS: 600
# global_step=211160, episodic_return=3.0
# global_step=211224, episodic_return=5.0
# global_step=211240, episodic_return=7.0
# global_step=211912, episodic_return=0.0
# SPS: 600
# global_step=211976, episodic_return=3.0
# global_step=212280, episodic_return=5.0
# global_step=212792, episodic_return=2.0
# SPS: 600
# global_step=213072, episodic_return=3.0
# global_step=213312, episodic_return=2.0
# global_step=213536, episodic_return=1.0
# global_step=213624, episodic_return=4.0
# global_step=213712, episodic_return=2.0
# global_step=213744, episodic_return=2.0
# SPS: 600
# global_step=214392, episodic_return=2.0
# global_step=214712, episodic_return=2.0
# global_step=214920, episodic_return=9.0
# SPS: 600
# - Prediction problem is randomly generated. This involves 2 NNs, fixed target network sets the prediction problem (find an embedding $f(O)$ for an observation) and predictor network trained on data collected (with the task to predict $\hat{f}(O)$) from the agent, minimizing MSE Loss $\text{MSE} = \| \hat{f}(x; \theta) - f(x) \|^{2}_2$.
# - Prediction error is expected to be higher in novel state (suprise state) that the agent is not familiar with.
# - $R=R_E+R_I$, thus, $V=V_E+V_I$.
# - Reward and Observation Normalization.

# %% [markdown]
# ### **3.2 Models**

# %% [markdown]
# #### **3.2.1 RND Models**

# %%
class RNDModel(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()

        self.input_size = input_size
        self.output_size = output_size

        feature_output = 7 * 7 * 64

        # Prediction network
        self.predictor = nn.Sequential(
            layer_init(nn.Conv2d(in_channels=1, out_channels=32, kernel_size=8, stride=4)),
            nn.LeakyReLU(),
            layer_init(nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2)),
            nn.LeakyReLU(),
            layer_init(nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)),
            nn.LeakyReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(feature_output, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
        )

        # Target network
        self.target = nn.Sequential(
            layer_init(nn.Conv2d(in_channels=1, out_channels=32, kernel_size=8, stride=4)),
            nn.LeakyReLU(),
            layer_init(nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2)),
            nn.LeakyReLU(),
            layer_init(nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)),
            nn.LeakyReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(feature_output, 512)),
        )

        # fixed the target network params
        for param in self.target.parameters():
            param.requires_grad = False

    def forward(self, next_obs):
        target_feature = self.target(next_obs)
        predict_feature = self.predictor(next_obs)

        return predict_feature, target_feature

# %%
class MovingSumOfReward:
    def __init__(self, gamma):
        self.moving_sum_of_reward = None
        self.gamma = gamma

    def update(self, rews):
        if self.moving_sum_of_reward is None:
            self.moving_sum_of_reward = rews
        else:
            self.moving_sum_of_reward = self.moving_sum_of_reward * self.gamma + rews
        return self.moving_sum_of_reward

# %% [markdown]
# #### **3.2.2 Main Training Loop**

# %%
env_id = params["env_id"]
exp_name = params["exp_name"]
seed = params["seed"]
run_name = f"{env_id}__{exp_name}__{seed}__{int(time.time())}"

envs = envpool.make(
    params["env_id"],
    env_type="gym",
    num_envs=params["num_envs"],
    episodic_life=True,
    reward_clip=True,
    seed=params["seed"],
    repeat_action_probability=0.25,
)

envs.num_envs = params["num_envs"]
envs.single_action_space = envs.action_space
print(f"The action space of the environment is {envs.single_action_space}")
envs.single_observation_space = envs.observation_space
print(f"The observation space of the environment is {envs.single_observation_space}")

envs = RecordEpisodeStatistics(envs)
assert isinstance(envs.action_space, gym.spaces.Discrete), "only discrete action space is supported"
# Out:
# The action space of the environment is Discrete(4)
# The observation space of the environment is Box(0, 255, (4, 84, 84), uint8)

# %%
# Set up agent and model
Agent = PPOAgent(envs, use_int_rews=True).to(device)
rnd_model = RNDModel(4, envs.single_action_space.n).to(device)
combined_parameters = list(Agent.parameters()) + list(rnd_model.predictor.parameters())
optimizer = optim.Adam(
    combined_parameters,
    lr=params["learning_rate"],
    eps=1e-5,
)

rew_runnning_mean_std = RunningMeanStd()
obs_runnning_mean_std = RunningMeanStd(shape=(1, 1, 84, 84))            # normalizing observation
discounted_reward = MovingSumOfReward(params["int_gamma"])

# %%
obs = torch.zeros((params["num_steps"], params["num_envs"]) + envs.single_observation_space.shape).to(device)  # (128, 4, 4, 84, 84)
actions = torch.zeros((params["num_steps"], params["num_envs"]) + envs.single_action_space.shape).to(device)   # (128, 4) 
logprobs = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
rewards = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
surprise_rewards = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
dones = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
ext_values = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
int_values = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
avg_returns = deque(maxlen=20)

# %%
batch_size = int(params["num_envs"] * params["num_steps"])                      # 4 * 128
minibatch_size = int(batch_size // params["num_minibatches"])
num_iterations = params["total_timesteps"] // batch_size                        # 20000000/(4*128) -> num iterations
global_step = 0
start_time = time.time()

next_obs = torch.Tensor(envs.reset()[0]).to(device)
next_done = torch.zeros(params["num_envs"]).to(device)

results_RND = {"global_step":[],
                "return_value":[],
                "intrinsic_reward":[]}

tracking_global_step = 0

# This will be used later when normalizing the observations
print("Start to initialize observation normalization parameter.....")
next_ob = []
for step in range(params["num_steps"] * params["num_iterations_obs_norm_init"]):
    acs = np.random.randint(0, envs.single_action_space.n, size=(params["num_envs"]))
    s, r, d, _ = envs.step(acs)
    next_ob += s[:, 3, :, :].reshape([-1, 1, 84, 84]).tolist()

    if len(next_ob) % (params["num_steps"] * params["num_envs"]) == 0:
        next_ob = np.stack(next_ob)
        obs_runnning_mean_std.update(next_ob)
        next_ob = []
print("End to initialize...")

for iteration in range(1, num_iterations + 1):
    if params["anneal_lr"]:
        updated_lr = (1.0 - (iteration - 1.0) / num_iterations) * params["learning_rate"]
        optimizer.param_groups[0]["lr"] = updated_lr

    # n-step rollouts
    for step in range(0, params["num_steps"]):
        global_step += 1 * params["num_envs"]
        obs[step] = next_obs
        dones[step] = next_done

        with torch.no_grad():
            value_ext, value_int = Agent.get_value(obs[step])                   # -> get the extrinsic and intrinsic value for current observation
            ext_values[step], int_values[step] = (
                value_ext.flatten(),
                value_int.flatten(),
            )
            action, logprob, _, _, _ = Agent.get_action_and_value(obs[step])

        actions[step] = action
        logprobs[step] = logprob

        next_obs, reward, done, info = envs.step(action.cpu().numpy())
        rewards[step] = torch.tensor(reward).to(device).view(-1)
        next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

        # Normalize obs for rnd
        rnd_next_obs = (
                (
                    (next_obs[:, 3, :, :].reshape(params["num_envs"], 1, 84, 84) - torch.from_numpy(obs_runnning_mean_std.mean).to(device))
                    / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var).to(device))
                ).clip(-5, 5)
            ).float()
        
        # Get the target F(O) and predict \hat(F)(O) value from rnd model
        target_next_feature, predict_next_feature = rnd_model.target(rnd_next_obs), rnd_model.predictor(rnd_next_obs)

        # Calculate the surprise reward
        surprise_rewards[step] = ((target_next_feature - predict_next_feature).pow(2).sum(1) / 2).data

        for idx, d in enumerate(done):
            # If done and no more live -> Get return
            if d and info["lives"][idx] == 0:
                avg_returns.append(info["r"][idx])
                epi_ret = np.average(avg_returns)
                print(
                    f"global_step={global_step}, episodic_return={info['r'][idx]}, surprise_reward={np.mean(surprise_rewards[step].cpu().numpy())}"
                )
                if global_step - tracking_global_step > 10000:
                    results_RND["global_step"].append(global_step)
                    results_RND["return_value"].append(info['r'][idx])
                    results_RND["intrinsic_reward"].append(np.mean(surprise_rewards[step].cpu().numpy()))
                    tracking_global_step = global_step

    # Calculate the discounted reward 
    surprise_reward_per_env = np.array(
        [discounted_reward.update(reward_per_step) for reward_per_step in surprise_rewards.cpu().data.numpy().T]
    )

    mean, std, count = (
        np.mean(surprise_reward_per_env),
        np.std(surprise_reward_per_env),
        len(surprise_reward_per_env),
    )
    
    rew_runnning_mean_std.update_from_moments(mean, std**2, count)

    # Normalize the curiousity_rewards based on the running_mean_std
    surprise_rewards /= np.sqrt(rew_runnning_mean_std.var)

    # Calculate value if not done
    with torch.no_grad():
        next_value_ext, next_value_int = Agent.get_value(next_obs)
        next_value_ext, next_value_int = next_value_ext.reshape(1, -1), next_value_int.reshape(1, -1)   # -> get next state values external & internal
        ext_advantages = torch.zeros_like(rewards, device=device)
        int_advantages = torch.zeros_like(surprise_rewards, device=device)
        ext_lastgaelam = 0
        int_lastgaelam = 0
        for t in reversed(range(params["num_steps"])):
            if t == params["num_steps"] - 1:
                ext_nextnonterminal = 1.0 - next_done
                int_nextnonterminal = 1.0
                ext_nextvalues = next_value_ext
                int_nextvalues = next_value_int
            else:
                ext_nextnonterminal = 1.0 - dones[t + 1]
                int_nextnonterminal = 1.0
                ext_nextvalues = ext_values[t + 1]
                int_nextvalues = int_values[t + 1]
            ext_delta = rewards[t] + params["gamma"] * ext_nextvalues * ext_nextnonterminal - ext_values[t]
            int_delta = surprise_rewards[t] + params["int_gamma"] * int_nextvalues * int_nextnonterminal - int_values[t]
            ext_advantages[t] = ext_lastgaelam = (
                ext_delta + params["gamma"] * params["gae_lambda"] * ext_nextnonterminal * ext_lastgaelam
            )
            int_advantages[t] = int_lastgaelam = (
                int_delta + params["int_gamma"] * params["gae_lambda"] * int_nextnonterminal * int_lastgaelam
            )
        ext_returns = ext_advantages + ext_values
        int_returns = int_advantages + int_values

    # Collect batch data for optimization
    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape(-1)
    b_ext_advantages = ext_advantages.reshape(-1)
    b_int_advantages = int_advantages.reshape(-1)
    b_ext_returns = ext_returns.reshape(-1)
    b_int_returns = int_returns.reshape(-1)
    b_ext_values = ext_values.reshape(-1)

    b_advantages = b_int_advantages * params["int_coef"] + b_ext_advantages * params["ext_coef"]

    obs_runnning_mean_std.update(b_obs[:, 3, :, :].reshape(-1, 1, 84, 84).cpu().numpy())

    # Optimizing the policy and value network
    b_inds = np.arange(batch_size)

    rnd_next_obs = (
        (
            (b_obs[:, 3, :, :].reshape(-1, 1, 84, 84) - torch.from_numpy(obs_runnning_mean_std.mean).to(device))
            / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var).to(device))
        ).clip(-5, 5)
    ).float()

    clipfracs = []
    for epoch in range(params["update_epochs"]):
        np.random.shuffle(b_inds)
        for start in range(0, batch_size, minibatch_size):
            end = start + minibatch_size
            mb_inds = b_inds[start:end]

            # Forward_loss
            predict_next_state_feature, target_next_state_feature = rnd_model(rnd_next_obs[mb_inds])
            forward_loss = F.mse_loss(
                predict_next_state_feature, target_next_state_feature.detach(), reduction="none"
            ).mean(-1)

            mask = torch.rand(len(forward_loss), device=device)
            mask = (mask < params["update_proportion"]).type(torch.FloatTensor).to(device)
            forward_loss = (forward_loss * mask).sum() / torch.max(
                mask.sum(), torch.tensor([1], device=device, dtype=torch.float32)
            )
            _, newlogprob, entropy, new_ext_values, new_int_values = Agent.get_action_and_value(
                b_obs[mb_inds], b_actions.long()[mb_inds]
            )
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            with torch.no_grad():
                # calculate approx_kl http://joschu.net/blog/kl-approx.html
                old_approx_kl = (-logratio).mean()
                approx_kl = ((ratio - 1) - logratio).mean()
                clipfracs += [((ratio - 1.0).abs() > params["clip_coef"]).float().mean().item()]

            mb_advantages = b_advantages[mb_inds]
            if params["norm_adv"]:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            # Policy loss
            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - params["clip_coef"], 1 + params["clip_coef"])
            pg_loss = torch.max(pg_loss1, pg_loss2).mean()

            # Value loss
            new_ext_values, new_int_values = new_ext_values.view(-1), new_int_values.view(-1)
            if params["clip_vloss"]:
                ext_value_loss_unclipped = (new_ext_values - b_ext_returns[mb_inds]) ** 2
                ext_v_clipped = b_ext_values[mb_inds] + torch.clamp(
                    new_ext_values - b_ext_values[mb_inds],
                    -params["clip_coef"],
                params["clip_coef"],
                )
                ext_value_loss_clipped = (ext_v_clipped - b_ext_returns[mb_inds]) ** 2
                ext_value_loss_max = torch.max(ext_value_loss_unclipped, ext_value_loss_clipped)
                ext_value_loss = 0.5 * ext_value_loss_max.mean()
            else:
                ext_value_loss = 0.5 * ((new_ext_values - b_ext_returns[mb_inds]) ** 2).mean()

            int_value_loss = 0.5 * ((new_int_values - b_int_returns[mb_inds]) ** 2).mean()

            value_loss = ext_value_loss + int_value_loss
            entropy_loss = entropy.mean()
            loss = pg_loss - params["ent_coef"] * entropy_loss + value_loss * params["vf_coef"] + forward_loss

            optimizer.zero_grad()
            loss.backward()
            if params["max_grad_norm"]:
                nn.utils.clip_grad_norm_(
                    combined_parameters,
                    params["max_grad_norm"],
                )
            optimizer.step()

        if params["target_kl"] is not None:
            if approx_kl > params["target_kl"]:
                break

    print("SPS:", int(global_step / (time.time() - start_time)))
# Out:
# Start to initialize observation normalization parameter.....
# End to initialize...
# global_step=144, episodic_return=2.0, surprise_reward=81.26419067382812
# global_step=184, episodic_return=0.0, surprise_reward=92.68743896484375
# global_step=344, episodic_return=1.0, surprise_reward=86.07556915283203
# global_step=400, episodic_return=2.0, surprise_reward=95.96742248535156
# global_step=440, episodic_return=4.0, surprise_reward=81.21531677246094
# global_step=736, episodic_return=1.0, surprise_reward=28.583105087280273
# global_step=752, episodic_return=2.0, surprise_reward=26.774555206298828
# SPS: 7
# global_step=1152, episodic_return=0.0, surprise_reward=16.01031494140625
# global_step=1344, episodic_return=0.0, surprise_reward=22.277902603149414
# global_step=1392, episodic_return=1.0, surprise_reward=21.906478881835938
# global_step=1432, episodic_return=1.0, surprise_reward=24.568817138671875
# global_step=1600, episodic_return=0.0, surprise_reward=25.376827239990234
# global_step=1656, episodic_return=1.0, surprise_reward=34.40625
# global_step=91096, episodic_return=1.0, surprise_reward=6.044561862945557
# SPS: 234
# global_step=91456, episodic_return=3.0, surprise_reward=6.079583168029785
# global_step=91648, episodic_return=0.0, surprise_reward=3.5304765701293945
# global_step=91664, episodic_return=0.0, surprise_reward=5.896980285644531
# global_step=91704, episodic_return=2.0, surprise_reward=7.486974239349365
# global_step=92096, episodic_return=0.0, surprise_reward=11.143614768981934
# SPS: 235
# global_step=92200, episodic_return=1.0, surprise_reward=7.60712194442749
# global_step=92424, episodic_return=1.0, surprise_reward=8.42439079284668
# global_step=92768, episodic_return=0.0, surprise_reward=7.427630424499512
# global_step=92880, episodic_return=3.0, surprise_reward=6.548145294189453
# global_step=93080, episodic_return=2.0, surprise_reward=6.850898742675781
# global_step=93168, episodic_return=2.0, surprise_reward=7.819806098937988
# SPS: 236
# global_step=93344, episodic_return=0.0, surprise_reward=11.795166969299316
# global_step=93512, episodic_return=3.0, surprise_reward=8.867725372314453
# global_step=93784, episodic_return=2.0, surprise_reward=10.303632736206055
# global_step=94088, episodic_return=2.0, surprise_reward=5.54108190536499
# global_step=94096, episodic_return=0.0, surprise_reward=5.633985996246338
# SPS: 237
# global_step=94544, episodic_return=1.0, surprise_reward=6.175538539886475
# global_step=94624, episodic_return=0.0, surprise_reward=8.940601348876953
# global_step=94736, episodic_return=2.0, surprise_reward=6.8960723876953125
# global_step=94800, episodic_return=3.0, surprise_reward=8.03571605682373
# global_step=95128, episodic_return=0.0, surprise_reward=7.3578081130981445
# SPS: 238
# global_step=95440, episodic_return=4.0, surprise_reward=8.759786605834961
# global_step=95616, episodic_return=0.0, surprise_reward=6.638489723205566
# global_step=95640, episodic_return=3.0, surprise_reward=5.4264912605285645
# global_step=95760, episodic_return=0.0, surprise_reward=4.097561836242676
# global_step=95760, episodic_return=0.0, surprise_reward=4.097561836242676
# global_step=96088, episodic_return=3.0, surprise_reward=6.178603172302246
# global_step=96192, episodic_return=0.0, surprise_reward=7.717594623565674
# SPS: 239
# global_step=96416, episodic_return=0.0, surprise_reward=6.98301362991333
# global_step=96936, episodic_return=4.0, surprise_reward=7.66876745223999
# global_step=97000, episodic_return=1.0, surprise_reward=6.991593360900879
# global_step=97056, episodic_return=1.0, surprise_reward=6.3343915939331055
# global_step=97200, episodic_return=0.0, surprise_reward=8.293010711669922
# SPS: 240
# global_step=97504, episodic_return=1.0, surprise_reward=7.328649520874023
# global_step=97536, episodic_return=3.0, surprise_reward=5.969447612762451
# global_step=97648, episodic_return=3.0, surprise_reward=5.065612316131592
# global_step=97816, episodic_return=1.0, surprise_reward=2.2727890014648438
# global_step=98056, episodic_return=0.0, surprise_reward=4.324066638946533
# SPS: 241
# global_step=98344, episodic_return=1.0, surprise_reward=4.850323677062988
# global_step=98384, episodic_return=1.0, surprise_reward=3.9142439365386963
# global_step=98480, episodic_return=0.0, surprise_reward=4.677331924438477
# global_step=98528, episodic_return=0.0, surprise_reward=4.200053691864014
# global_step=98632, episodic_return=1.0, surprise_reward=4.528049468994141
# global_step=98648, episodic_return=0.0, surprise_reward=3.8043408393859863
# global_step=98864, episodic_return=0.0, surprise_reward=3.0866148471832275
# SPS: 242
# global_step=99352, episodic_return=0.0, surprise_reward=3.649954080581665
# global_step=99440, episodic_return=0.0, surprise_reward=3.4140055179595947
# global_step=99464, episodic_return=1.0, surprise_reward=3.9843530654907227
# global_step=99528, episodic_return=0.0, surprise_reward=5.212906360626221
# global_step=99560, episodic_return=0.0, surprise_reward=4.428136825561523
# global_step=99784, episodic_return=0.0, surprise_reward=5.2840471267700195
# global_step=99832, episodic_return=0.0, surprise_reward=6.691919326782227
# global_step=100040, episodic_return=1.0, surprise_reward=4.109762668609619
# global_step=100352, episodic_return=0.0, surprise_reward=3.101039409637451
# SPS: 243
# global_step=100440, episodic_return=0.0, surprise_reward=3.021618366241455
# global_step=100624, episodic_return=0.0, surprise_reward=5.61091423034668
# global_step=100704, episodic_return=1.0, surprise_reward=5.404933452606201
# global_step=100760, episodic_return=1.0, surprise_reward=5.763031005859375
# global_step=101016, episodic_return=1.0, surprise_reward=4.257224082946777
# global_step=101040, episodic_return=0.0, surprise_reward=3.695481538772583
# global_step=101096, episodic_return=1.0, surprise_reward=5.5424909591674805
# SPS: 244
# global_step=101760, episodic_return=0.0, surprise_reward=8.146379470825195
# global_step=101984, episodic_return=1.0, surprise_reward=7.981127738952637
# global_step=102120, episodic_return=2.0, surprise_reward=8.873526573181152
# global_step=102224, episodic_return=2.0, surprise_reward=6.261995315551758
# global_step=102248, episodic_return=1.0, surprise_reward=6.326375961303711
# global_step=102368, episodic_return=3.0, surprise_reward=7.889713764190674
# SPS: 245
# global_step=102736, episodic_return=2.0, surprise_reward=3.9541070461273193
# global_step=103008, episodic_return=0.0, surprise_reward=8.15989875793457
# global_step=103056, episodic_return=3.0, surprise_reward=8.845325469970703
# global_step=103168, episodic_return=0.0, surprise_reward=6.724639892578125
# global_step=103400, episodic_return=1.0, surprise_reward=12.884653091430664
# SPS: 246
# global_step=103640, episodic_return=1.0, surprise_reward=9.252340316772461
# global_step=103872, episodic_return=4.0, surprise_reward=9.655142784118652
# global_step=104232, episodic_return=0.0, surprise_reward=6.779314041137695
# global_step=104328, episodic_return=2.0, surprise_reward=6.523650169372559
# global_step=104336, episodic_return=3.0, surprise_reward=6.412280559539795
# global_step=104408, episodic_return=0.0, surprise_reward=5.8990983963012695
# SPS: 247
# global_step=104672, episodic_return=2.0, surprise_reward=7.690271377563477
# global_step=104928, episodic_return=0.0, surprise_reward=9.254720687866211
# global_step=105120, episodic_return=3.0, surprise_reward=7.621078014373779
# global_step=105408, episodic_return=0.0, surprise_reward=8.84855842590332
# SPS: 248
# global_step=105504, episodic_return=3.0, surprise_reward=6.501399993896484
# global_step=105680, episodic_return=1.0, surprise_reward=5.580659866333008
# global_step=105704, episodic_return=1.0, surprise_reward=4.947523593902588
# global_step=105856, episodic_return=2.0, surprise_reward=3.8231396675109863
# global_step=105992, episodic_return=1.0, surprise_reward=4.34680700302124
# global_step=106424, episodic_return=0.0, surprise_reward=6.266694068908691
# global_step=106496, episodic_return=1.0, surprise_reward=5.866567611694336
# SPS: 249
# global_step=106736, episodic_return=0.0, surprise_reward=5.695637226104736
# global_step=106856, episodic_return=1.0, surprise_reward=9.857404708862305
# global_step=107136, episodic_return=1.0, surprise_reward=7.47513484954834
# global_step=107368, episodic_return=1.0, surprise_reward=11.582649230957031
# SPS: 250
# global_step=107808, episodic_return=3.0, surprise_reward=16.868745803833008
# global_step=107912, episodic_return=1.0, surprise_reward=13.384599685668945
# global_step=108328, episodic_return=3.0, surprise_reward=18.983901977539062
# global_step=108472, episodic_return=7.0, surprise_reward=15.11238956451416
# SPS: 251
# global_step=108672, episodic_return=2.0, surprise_reward=3.6928999423980713
# global_step=108744, episodic_return=1.0, surprise_reward=8.19449520111084
# global_step=108904, episodic_return=0.0, surprise_reward=8.860852241516113
# global_step=109072, episodic_return=1.0, surprise_reward=13.270186424255371
# global_step=109264, episodic_return=4.0, surprise_reward=15.324063301086426
# global_step=109528, episodic_return=4.0, surprise_reward=8.970951080322266
# SPS: 252
# global_step=109664, episodic_return=1.0, surprise_reward=3.127668619155884
# global_step=109696, episodic_return=0.0, surprise_reward=3.1321980953216553
# global_step=109752, episodic_return=1.0, surprise_reward=6.810510635375977
# global_step=110136, episodic_return=0.0, surprise_reward=7.792025566101074
# global_step=110264, episodic_return=0.0, surprise_reward=5.904254913330078
# global_step=110488, episodic_return=2.0, surprise_reward=3.355245590209961
# global_step=110528, episodic_return=0.0, surprise_reward=5.941837787628174
# SPS: 252
# global_step=110680, episodic_return=0.0, surprise_reward=4.6727447509765625
# global_step=110992, episodic_return=1.0, surprise_reward=8.81081485748291
# global_step=111072, episodic_return=1.0, surprise_reward=6.495267868041992
# global_step=111544, episodic_return=1.0, surprise_reward=7.92038631439209
# SPS: 253
# global_step=111696, episodic_return=12.0, surprise_reward=7.382239818572998
# global_step=111784, episodic_return=1.0, surprise_reward=5.693364143371582
# global_step=111896, episodic_return=2.0, surprise_reward=5.595509052276611
# global_step=112032, episodic_return=0.0, surprise_reward=6.558468341827393
# global_step=112080, episodic_return=1.0, surprise_reward=6.19331693649292
# SPS: 254
# global_step=112824, episodic_return=0.0, surprise_reward=3.4759867191314697
# global_step=112872, episodic_return=1.0, surprise_reward=3.7855091094970703
# global_step=112872, episodic_return=4.0, surprise_reward=3.7855091094970703
# global_step=112896, episodic_return=1.0, surprise_reward=6.562043190002441
# global_step=113032, episodic_return=0.0, surprise_reward=3.0824389457702637
# global_step=113080, episodic_return=0.0, surprise_reward=6.005134105682373
# ...
# global_step=5812616, episodic_return=19.0, surprise_reward=9.665050506591797
# SPS: 467
# global_step=5814088, episodic_return=30.0, surprise_reward=11.55438232421875
# SPS: 467
# SPS: 467
# SPS: 467
# global_step=5816376, episodic_return=61.0, surprise_reward=11.768896102905273
# SPS: 467
# global_step=5817720, episodic_return=36.0, surprise_reward=14.567203521728516
# global_step=5818328, episodic_return=16.0, surprise_reward=16.48548698425293
# SPS: 467
# SPS: 467
# global_step=5819424, episodic_return=40.0, surprise_reward=19.706897735595703
# global_step=5820072, episodic_return=50.0, surprise_reward=17.484975814819336
# SPS: 467
# SPS: 469
# global_step=5972504, episodic_return=23.0, surprise_reward=5.6400861740112305
# SPS: 469
# global_step=5973008, episodic_return=36.0, surprise_reward=7.035039901733398
# global_step=5973480, episodic_return=18.0, surprise_reward=6.17637825012207
# SPS: 469
# global_step=5974056, episodic_return=10.0, surprise_reward=5.396749496459961
# SPS: 469
# global_step=5976032, episodic_return=24.0, surprise_reward=9.854056358337402
# SPS: 469
# global_step=5976720, episodic_return=36.0, surprise_reward=8.486750602722168
# SPS: 469
# SPS: 469
# SPS: 469
# global_step=5980136, episodic_return=44.0, surprise_reward=12.721071243286133
# SPS: 469
# global_step=5980688, episodic_return=36.0, surprise_reward=12.396890640258789
# global_step=5980856, episodic_return=42.0, surprise_reward=9.228238105773926
# SPS: 469
# global_step=5981560, episodic_return=39.0, surprise_reward=9.076284408569336
# SPS: 469
# SPS: 469
# global_step=5983360, episodic_return=23.0, surprise_reward=10.479363441467285
# global_step=5983816, episodic_return=51.0, surprise_reward=13.355134010314941
# global_step=5983856, episodic_return=45.0, surprise_reward=9.331762313842773
# global_step=5984168, episodic_return=37.0, surprise_reward=8.180731773376465
# SPS: 469
# SPS: 469
# SPS: 469
# global_step=5986648, episodic_return=29.0, surprise_reward=7.443601608276367
# SPS: 469
# global_step=5987408, episodic_return=19.0, surprise_reward=5.998587608337402
# global_step=5987528, episodic_return=19.0, surprise_reward=5.090510845184326
# global_step=5987936, episodic_return=17.0, surprise_reward=7.526988506317139
# SPS: 469
# global_step=5989120, episodic_return=23.0, surprise_reward=9.35826301574707
# SPS: 469
# SPS: 469
# SPS: 469
# global_step=5991896, episodic_return=26.0, surprise_reward=12.12991714477539
# SPS: 469
# global_step=5992488, episodic_return=37.0, surprise_reward=13.115880966186523
# SPS: 469
# global_step=5993896, episodic_return=52.0, surprise_reward=17.1711368560791
# SPS: 469
# SPS: 469
# global_step=5995616, episodic_return=34.0, surprise_reward=12.28006362915039
# SPS: 469
# global_step=5996912, episodic_return=27.0, surprise_reward=17.073989868164062
# global_step=5996952, episodic_return=46.0, surprise_reward=14.78598690032959
# SPS: 469
# SPS: 469
# global_step=5998616, episodic_return=49.0, surprise_reward=17.69484519958496
# global_step=5998912, episodic_return=54.0, surprise_reward=13.994898796081543
# SPS: 469

# %%
envs.close()

# %%
torch.save(Agent, "pretrained_models/ppo_for_RND_atari.pth")
torch.save(rnd_model, "pretrained_models/rnd_atari.pth")

# %%
# Extract data from results_RND
rnd_global_step = results_RND["global_step"]
rnd_return_value = results_RND["return_value"]
rnd_intrinsic_reward = results_RND["intrinsic_reward"]

df_rnd = pd.DataFrame({'global_step': rnd_global_step, 'return_value': rnd_return_value, 'intrinsic_reward': rnd_intrinsic_reward})
# Save DataFrames to CSV files
df_rnd.to_csv('results_rnd_atari.csv', index=False)

# %% [markdown]
# ## **4. Curiosity-driven Exploration by Self-supervised Prediction**

# %% [markdown]
# ### **4.1 Key Points**

# %% [markdown]
# - The architecture is a network with two tasks, which we refer to as inverse prediction task and forward prediction task. The network, firstly, encodes the state $s_{t}$ and state $s_{t+1}$ into feature vectors $\phi(s_{t})$ and $\phi(s_{t+1})$. The network used the two encoded vectors as input to predict action $a_t$ in the inverse prediction task. It then used the result feature vectors $\phi(s_{t})$ and action $a_t$ as input to predict $\phi(s_{t+1})$.
# - The loss for the inverse prediction task is a cross entropy loss between the action chosen by the architecture and the real action that the agent has taken. The loss for the forward prediction task is an MSE loss.
# - Prediction error is expected to be higher in novel state (suprise state) that the agent is not familiar with.
# - Reward and Observation Normalization.
#
# <div style="text-align:center">
#     <img src="./image/Curiousity-driven exploration.png" alt="AutoEncoder forr Count Based Exploration" width="420" height="350">
# </div>

# %% [markdown]
# ### **4.2 Models**

# %% [markdown]
# #### **4.2.1 ICM Models**

# %%
class ICMModel(nn.Module):
    def __init__(self, input_size, output_size, device, use_cuda=True):
        super(ICMModel, self).__init__()

        self.input_size = input_size
        self.output_size = output_size
        self.eta = 1.
        self.device = device

        feature_output = 7 * 7 * 64
        self.feature = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=32,
                kernel_size=8,
                stride=4),
            nn.LeakyReLU(),
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=4,
                stride=2),
            nn.LeakyReLU(),
            nn.Conv2d(
                in_channels=64,
                out_channels=64,
                kernel_size=3,
                stride=1),
            nn.LeakyReLU(),
            nn.Flatten(),
            nn.Linear(feature_output, 512)
        )

        self.inverse_net = nn.Sequential(
            nn.Linear(512 * 2, 512),
            nn.ReLU(),
            nn.Linear(512, output_size)
        )

        self.residual = [nn.Sequential(
            nn.Linear(output_size + 512, 512),
            nn.LeakyReLU(),
            nn.Linear(512, 512),
        ).to(self.device)] * 4

        self.forward_net_1 = nn.Sequential(
            nn.Linear(output_size + 512, 512),
            nn.LeakyReLU()
        )
        self.forward_net_2 = nn.Sequential(
            nn.Linear(output_size + 512, 512),
        )

        for p in self.modules():
            if isinstance(p, nn.Conv2d):
                init.kaiming_uniform_(p.weight)
                p.bias.data.zero_()

            if isinstance(p, nn.Linear):
                init.kaiming_uniform_(p.weight, a=1.0)
                p.bias.data.zero_()

    def forward(self, inputs):
        state, next_state, action = inputs

        encode_state = self.feature(state)
        encode_next_state = self.feature(next_state)
        # get pred action
        pred_action = torch.cat((encode_state, encode_next_state), 1)
        pred_action = self.inverse_net(pred_action)
        # ---------------------

        # get pred next state
        pred_next_state_feature_orig = torch.cat((encode_state, action), 1)
        pred_next_state_feature_orig = self.forward_net_1(pred_next_state_feature_orig)

        # residual
        for i in range(2):
            pred_next_state_feature = self.residual[i * 2](torch.cat((pred_next_state_feature_orig, action), 1))
            pred_next_state_feature_orig = self.residual[i * 2 + 1](
                torch.cat((pred_next_state_feature, action), 1)) + pred_next_state_feature_orig

        pred_next_state_feature = self.forward_net_2(torch.cat((pred_next_state_feature_orig, action), 1))

        real_next_state_feature = encode_next_state
        return real_next_state_feature, pred_next_state_feature, pred_action
    
    def compute_intrinsic_reward(self, state, next_state, action):
        action_onehot = torch.zeros(len(action), self.output_size, device=self.device)
        action_onehot.scatter_(1, action.view(len(action), -1), 1)

        real_next_state_feature, pred_next_state_feature, pred_action = self.forward([state, next_state, action_onehot])
        intrinsic_reward = self.eta * F.mse_loss(real_next_state_feature, pred_next_state_feature, reduction='none').mean(-1)
        return intrinsic_reward
    
    def inference(self, states, next_states, actions):
        action_onehot = torch.zeros(len(actions), self.output_size, device=self.device)
        action_onehot.scatter_(1, actions.view(-1, 1).long(), 1)

        real_next_state_feature, pred_next_state_feature, pred_action = self.forward([states, next_states, action_onehot])
        return real_next_state_feature, pred_next_state_feature, pred_action

# %%
class MovingSumOfReward:
    def __init__(self, gamma):
        self.moving_sum_of_reward = None
        self.gamma = gamma

    def update(self, rews):
        if self.moving_sum_of_reward is None:
            self.moving_sum_of_reward = rews
        else:
            self.moving_sum_of_reward = self.moving_sum_of_reward * self.gamma + rews
        return self.moving_sum_of_reward

# %% [markdown]
# #### **4.2.2 Main Training Loop**

# %%
env_id = params["env_id"]
exp_name = params["exp_name"]
seed = params["seed"]
run_name = f"{env_id}__{exp_name}__{seed}__{int(time.time())}"

envs = envpool.make(
    params["env_id"],
    env_type="gym",
    num_envs=params["num_envs"],
    episodic_life=True,
    reward_clip=True,
    seed=params["seed"],
    repeat_action_probability=0.25,
)

envs.num_envs = params["num_envs"]
envs.single_action_space = envs.action_space
print(f"The action space of the environment is {envs.single_action_space}")
envs.single_observation_space = envs.observation_space
print(f"The observation space of the environment is {envs.single_observation_space}")

envs = RecordEpisodeStatistics(envs)
assert isinstance(envs.action_space, gym.spaces.Discrete), "only discrete action space is supported"
# Out:
# The action space of the environment is Discrete(4)
# The observation space of the environment is Box(0, 255, (4, 84, 84), uint8)

# %%
input_size = envs.single_observation_space
output_size = envs.single_action_space.n

is_load_model = False
is_render = False
use_cuda = params["cuda"]
use_gae = True
use_noisy_net = False
lam = params["gae_lambda"]
num_step = params["num_steps"]
learning_rate = params["learning_rate"]
entropy_coef = params["ent_coef"]
gamma = params["gamma"]
clip_grad_norm = params["max_grad_norm"]
pre_obs_norm_step = params["num_iterations_obs_norm_init"]

# Set up agent and model
icm = ICMModel(input_size, output_size, device).to(device)
Agent = PPOAgent(envs, use_int_rews=True).to(device)

combined_parameters = list(Agent.parameters() ) + list(icm.parameters())
optimizer = optim.Adam(
    combined_parameters,
    lr=params["learning_rate"],
    eps=1e-5,
)

rew_runnning_mean_std = RunningMeanStd()
obs_runnning_mean_std = RunningMeanStd(shape=(1, 1, 84, 84))            # normalizing observation
discounted_reward = MovingSumOfReward(params["int_gamma"])

# %%
obs = torch.zeros((params["num_steps"]+1, params["num_envs"]) + envs.single_observation_space.shape).to(device)  # (128, 4,, 4, 84, 84)

# %%
batch_size = int(params["num_envs"] * params["num_steps"])                      # 4 * 128
minibatch_size = int(batch_size // params["num_minibatches"])
num_iterations = params["total_timesteps"] // batch_size                        # 20000000/(4*128) -> num iterations
global_step = 0
tracking_global_step = 0
start_time = time.time()

next_obs = torch.Tensor(envs.reset()[0]).to(device)
next_done = torch.zeros(params["num_envs"]).to(device)

results_ICM = {"global_step":[],
                "return_value":[],
                "intrinsic_reward":[]}

print("Start to initialize observation normalization parameter.....")
next_ob = []
for step in range(params["num_steps"] * params["num_iterations_obs_norm_init"]):
    acs = np.random.randint(0, envs.single_action_space.n, size=(params["num_envs"]))
    s, r, d, _ = envs.step(acs)
    next_ob += s[:, 3, :, :].reshape([-1, 1, 84, 84]).tolist()

    if len(next_ob) % (params["num_steps"] * params["num_envs"]) == 0:
        next_ob = np.stack(next_ob)
        obs_runnning_mean_std.update(next_ob)
        next_ob = []
print("End to initialize...")

for iteration in range(1, num_iterations + 1):
    actions = torch.zeros((params["num_steps"], params["num_envs"]) + envs.single_action_space.shape).to(device)   # (128, 4) 
    logprobs = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    rewards = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    surprise_rewards = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    dones = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    ext_values = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    int_values = torch.zeros((params["num_steps"], params["num_envs"])).to(device)
    # Calculate the new learning rate as according to the annealing rate if needed.
    if params["anneal_lr"]:
        updated_lr = (1.0 - (iteration - 1.0) / num_iterations) * params["learning_rate"]
        optimizer.param_groups[0]["lr"] = updated_lr

    for step in range(0, params["num_steps"]):
        global_step += 1 * params["num_envs"]
        obs[step] = next_obs
        dones[step] = next_done

        with torch.no_grad():
            value_ext, value_int = Agent.get_value(obs[step])                   # -> get the extrinsic and intrinsic value for current observation
            ext_values[step], int_values[step] = (
                value_ext.flatten(),
                value_int.flatten(),
            )
            action, logprob, _, _, _ = Agent.get_action_and_value(obs[step])
        
        actions[step] = action
        logprobs[step] = logprob        
        next_obs, reward, done, info = envs.step(action.cpu().numpy())
        rewards[step] = torch.tensor(reward).to(device).view(-1)
        next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)
        # next_obs_b[step] = next_obs

        icm_obs = (                (
                    (obs[step][:, 3, :, :].reshape(params["num_envs"], 1, 84, 84).cpu() - torch.from_numpy(obs_runnning_mean_std.mean))
                    / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var))
                ).clip(-5, 5)
            ).float()
        icm_next_obs = (
                (
                    (next_obs[:, 3, :, :].reshape(params["num_envs"], 1, 84, 84).cpu() - torch.from_numpy(obs_runnning_mean_std.mean))
                    / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var))
                ).clip(-5, 5)
            ).float()
        
        surprise_rewards[step] = icm.compute_intrinsic_reward(icm_obs.to(device), icm_next_obs.to(device), actions[step].long())

        for idx, d in enumerate(done):
            # If done and no more live -> Get return
            if d and info["lives"][idx] == 0:
                print(
                    f"global_step={global_step}, episodic_return={info['r'][idx]}, surprise_reward={np.mean(surprise_rewards[step].data.cpu().numpy())}"
                )
                if global_step - tracking_global_step > 10000:
                    results_ICM["global_step"].append(global_step)
                    results_ICM["return_value"].append(info['r'][idx])
                    results_ICM["intrinsic_reward"].append(np.mean(surprise_rewards[step].data.cpu().numpy()))
                    tracking_global_step = global_step
            
    obs[-1] = next_obs

    # Calculate the discounted reward 
    surprise_reward_per_env = np.array(
        [discounted_reward.update(reward_per_step) for reward_per_step in surprise_rewards.cpu().data.numpy().T]
    )

    mean, std, count = (
        np.mean(surprise_reward_per_env),
        np.std(surprise_reward_per_env),
        len(surprise_reward_per_env),
    )
    
    rew_runnning_mean_std.update_from_moments(mean, std**2, count)

    # Normalize the curiousity_rewards based on the running_mean_std
    surprise_rewards /= np.sqrt(rew_runnning_mean_std.var)

    # Calculate value if not done
    with torch.no_grad():
        next_value_ext, next_value_int = Agent.get_value(next_obs)
        next_value_ext, next_value_int = next_value_ext.reshape(1, -1), next_value_int.reshape(1, -1)   # -> get next state values external & internal
        ext_advantages = torch.zeros_like(rewards, device=device)
        int_advantages = torch.zeros_like(surprise_rewards, device=device)
        ext_lastgaelam = 0
        int_lastgaelam = 0
        for t in reversed(range(params["num_steps"])):
            if t == params["num_steps"] - 1:
                ext_nextnonterminal = 1.0 - next_done
                int_nextnonterminal = 1.0
                ext_nextvalues = next_value_ext
                int_nextvalues = next_value_int
            else:
                ext_nextnonterminal = 1.0 - dones[t + 1]
                int_nextnonterminal = 1.0
                ext_nextvalues = ext_values[t + 1]
                int_nextvalues = int_values[t + 1]
            ext_delta = rewards[t] + params["gamma"] * ext_nextvalues * ext_nextnonterminal - ext_values[t]
            int_delta = surprise_rewards[t] + params["int_gamma"] * int_nextvalues * int_nextnonterminal - int_values[t]
            ext_advantages[t] = ext_lastgaelam = (
                ext_delta + params["gamma"] * params["gae_lambda"] * ext_nextnonterminal * ext_lastgaelam
            )
            int_advantages[t] = int_lastgaelam = (
                int_delta + params["int_gamma"] * params["gae_lambda"] * int_nextnonterminal * int_lastgaelam
            )
        ext_returns = ext_advantages + ext_values
        int_returns = int_advantages + int_values
    
    # Collect batch data for optimization
    b_obs = obs[:-1].reshape((-1,) + envs.single_observation_space.shape)
    b_next_obs = obs[1:].reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape(-1)
    b_ext_advantages = ext_advantages.reshape(-1)
    b_int_advantages = int_advantages.reshape(-1)
    b_ext_returns = ext_returns.reshape(-1)
    b_int_returns = int_returns.reshape(-1)
    b_ext_values = ext_values.reshape(-1)

    b_advantages = b_int_advantages * params["int_coef"] + b_ext_advantages * params["ext_coef"]

    obs_runnning_mean_std.update(b_obs[:, 3, :, :].reshape(-1, 1, 84, 84).cpu().numpy())

    # Optimizing the policy and value network
    b_inds = np.arange(batch_size)
    icm_obs = (
        (
            (b_obs[:, 3, :, :].reshape(-1, 1, 84, 84).cpu() - torch.from_numpy(obs_runnning_mean_std.mean))
            / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var))
        ).clip(-5, 5)
    ).float()

    icm_next_obs = (
        (
            (b_next_obs[:, 3, :, :].reshape(-1, 1, 84, 84).cpu() - torch.from_numpy(obs_runnning_mean_std.mean))
            / torch.sqrt(torch.from_numpy(obs_runnning_mean_std.var))
        ).clip(-5, 5)
    ).float()

    ce = nn.CrossEntropyLoss()
    forward_mse = nn.MSELoss()

    for epoch in range(params["update_epochs"]):
        np.random.shuffle(b_inds)
        for start in range(0, batch_size, minibatch_size):
            end = start + minibatch_size
            mb_inds = b_inds[start:end]

            real_next_state_feature, pred_next_state_feature, pred_action = icm.inference(icm_obs[mb_inds].to(device), icm_next_obs[mb_inds].to(device), b_actions[mb_inds])

            inverse_loss = ce(
                    pred_action, b_actions[mb_inds].long())

            forward_loss = forward_mse(
                    pred_next_state_feature, real_next_state_feature.detach())

            _, newlogprob, entropy, new_ext_values, new_int_values = Agent.get_action_and_value(
                b_obs[mb_inds], b_actions.long()[mb_inds]
            )
            
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            mb_advantages = b_advantages[mb_inds]
            if params["norm_adv"]:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            # Policy loss
            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - params["clip_coef"], 1 + params["clip_coef"])
            pg_loss = torch.max(pg_loss1, pg_loss2).mean()

            # Value loss
            new_ext_values, new_int_values = new_ext_values.view(-1), new_int_values.view(-1)
            if params["clip_vloss"]:
                ext_value_loss_unclipped = (new_ext_values - b_ext_returns[mb_inds]) ** 2
                ext_v_clipped = b_ext_values[mb_inds] + torch.clamp(
                    new_ext_values - b_ext_values[mb_inds],
                    -params["clip_coef"],
                params["clip_coef"],
                )
                ext_value_loss_clipped = (ext_v_clipped - b_ext_returns[mb_inds]) ** 2
                ext_value_loss_max = torch.max(ext_value_loss_unclipped, ext_value_loss_clipped)
                ext_value_loss = 0.5 * ext_value_loss_max.mean()
            else:
                ext_value_loss = 0.5 * ((new_ext_values - b_ext_returns[mb_inds]) ** 2).mean()

            int_value_loss = 0.5 * ((new_int_values - b_int_returns[mb_inds]) ** 2).mean()

            value_loss = ext_value_loss + int_value_loss
            entropy_loss = entropy.mean()

            loss = pg_loss - params["ent_coef"] * entropy_loss + value_loss * params["vf_coef"] + forward_loss + inverse_loss
        

            optimizer.zero_grad()
            loss.backward()
            if params["max_grad_norm"]:
                nn.utils.clip_grad_norm_(
                    combined_parameters,
                    params["max_grad_norm"],
                )
            optimizer.step()

    print("SPS:", int(global_step / (time.time() - start_time)))
# Out:
# Start to initialize observation normalization parameter.....
# End to initialize...
# global_step=544, episodic_return=0.0, surprise_reward=0.15259361267089844
# global_step=744, episodic_return=1.0, surprise_reward=0.1549212485551834
# global_step=768, episodic_return=3.0, surprise_reward=0.14374038577079773
# global_step=808, episodic_return=4.0, surprise_reward=0.10556373000144958
# global_step=856, episodic_return=1.0, surprise_reward=0.09079968929290771
# global_step=1016, episodic_return=2.0, surprise_reward=0.07946673780679703
# SPS: 6
# global_step=1552, episodic_return=0.0, surprise_reward=0.09167813509702682
# global_step=1592, episodic_return=2.0, surprise_reward=0.10501880943775177
# global_step=1648, episodic_return=2.0, surprise_reward=0.0935785174369812
# global_step=1872, episodic_return=0.0, surprise_reward=0.08933804929256439
# SPS: 12
# global_step=2144, episodic_return=1.0, surprise_reward=0.07605981081724167
# global_step=2312, episodic_return=2.0, surprise_reward=0.0729929506778717
# global_step=2552, episodic_return=2.0, surprise_reward=0.05309179425239563
# global_step=2832, episodic_return=3.0, surprise_reward=0.06924856454133987
# SPS: 18
# global_step=3312, episodic_return=0.0, surprise_reward=0.10155481100082397
# global_step=3400, episodic_return=3.0, surprise_reward=0.09357358515262604
# global_step=3456, episodic_return=2.0, surprise_reward=0.09065991640090942
# global_step=3528, episodic_return=3.0, surprise_reward=0.08636881411075592
# global_step=3936, episodic_return=1.0, surprise_reward=0.10270730406045914
# global_step=4072, episodic_return=1.0, surprise_reward=0.10197225213050842
# SPS: 23
# global_step=4288, episodic_return=5.0, surprise_reward=0.08778974413871765
# global_step=4368, episodic_return=0.0, surprise_reward=0.06320145726203918
# global_step=4408, episodic_return=4.0, surprise_reward=0.06583595275878906
# global_step=4576, episodic_return=0.0, surprise_reward=0.041456855833530426
# global_step=4728, episodic_return=1.0, surprise_reward=0.037976525723934174
# global_step=5096, episodic_return=0.0, surprise_reward=0.04523799195885658
# SPS: 28
# global_step=5288, episodic_return=0.0, surprise_reward=0.071886345744133
# global_step=5528, episodic_return=3.0, surprise_reward=0.08781830966472626
# global_step=5664, episodic_return=2.0, surprise_reward=0.08865978568792343
# global_step=5984, episodic_return=1.0, surprise_reward=0.10293476283550262
# global_step=6016, episodic_return=1.0, surprise_reward=0.0972675159573555
# global_step=6136, episodic_return=0.0, surprise_reward=0.08236558735370636
# SPS: 34
# global_step=6352, episodic_return=3.0, surprise_reward=0.08138712495565414
# global_step=6576, episodic_return=3.0, surprise_reward=0.06245289742946625
# global_step=6888, episodic_return=1.0, surprise_reward=0.04432973265647888
# global_step=6920, episodic_return=2.0, surprise_reward=0.05062152445316315
# global_step=6984, episodic_return=0.0, surprise_reward=0.05694682151079178
# global_step=7056, episodic_return=1.0, surprise_reward=0.0436595156788826
# global_step=7064, episodic_return=0.0, surprise_reward=0.03261927515268326
# SPS: 39
# global_step=7296, episodic_return=0.0, surprise_reward=0.025472084060311317
# global_step=7888, episodic_return=0.0, surprise_reward=0.03333127498626709
# global_step=7920, episodic_return=3.0, surprise_reward=0.03604907542467117
# global_step=7952, episodic_return=1.0, surprise_reward=0.036448754370212555
# global_step=8008, episodic_return=0.0, surprise_reward=0.03693403676152229
# SPS: 43
# global_step=8312, episodic_return=1.0, surprise_reward=0.026578273624181747
# global_step=8400, episodic_return=1.0, surprise_reward=0.033542606979608536
# global_step=8680, episodic_return=1.0, surprise_reward=0.026943452656269073
# global_step=8736, episodic_return=2.0, surprise_reward=0.03587896004319191
# global_step=8896, episodic_return=0.0, surprise_reward=0.025719156488776207
# global_step=8904, episodic_return=0.0, surprise_reward=0.02561001665890217
# global_step=8920, episodic_return=0.0, surprise_reward=0.03843693435192108
# SPS: 48
# global_step=9488, episodic_return=1.0, surprise_reward=0.04197061434388161
# global_step=9496, episodic_return=1.0, surprise_reward=0.039179131388664246
# global_step=9776, episodic_return=1.0, surprise_reward=0.048389360308647156
# global_step=10104, episodic_return=1.0, surprise_reward=0.04475412517786026
# global_step=10168, episodic_return=1.0, surprise_reward=0.04849034920334816
# SPS: 53
# global_step=10280, episodic_return=1.0, surprise_reward=0.03438913822174072
# global_step=10304, episodic_return=2.0, surprise_reward=0.036383986473083496
# global_step=10456, episodic_return=0.0, surprise_reward=0.06663767993450165
# global_step=10800, episodic_return=3.0, surprise_reward=0.06581975519657135
# global_step=10832, episodic_return=1.0, surprise_reward=0.05341443419456482
# global_step=11048, episodic_return=1.0, surprise_reward=0.05267665535211563
# SPS: 57
# global_step=11560, episodic_return=2.0, surprise_reward=0.061117276549339294
# global_step=11720, episodic_return=1.0, surprise_reward=0.049554549157619476
# global_step=11760, episodic_return=1.0, surprise_reward=0.05422353371977806
# global_step=11768, episodic_return=2.0, surprise_reward=0.05648093670606613
# global_step=11832, episodic_return=0.0, surprise_reward=0.06591098010540009
# SPS: 61
# global_step=12384, episodic_return=1.0, surprise_reward=0.09554905444383621
# global_step=12456, episodic_return=2.0, surprise_reward=0.09244397282600403
# global_step=12488, episodic_return=3.0, surprise_reward=0.07454971224069595
# global_step=12856, episodic_return=0.0, surprise_reward=0.07616926729679108
# global_step=12880, episodic_return=0.0, surprise_reward=0.07357841730117798
# global_step=13072, episodic_return=1.0, surprise_reward=0.0949370488524437
# SPS: 65
# global_step=13432, episodic_return=0.0, surprise_reward=0.14875657856464386
# global_step=13568, episodic_return=3.0, surprise_reward=0.09310048818588257
# global_step=13608, episodic_return=0.0, surprise_reward=0.09239578247070312
# global_step=13640, episodic_return=1.0, surprise_reward=0.08673831820487976
# global_step=13864, episodic_return=0.0, surprise_reward=0.11938436329364777
# global_step=14016, episodic_return=4.0, surprise_reward=0.12776440382003784
# global_step=14040, episodic_return=0.0, surprise_reward=0.10500361025333405
# global_step=14224, episodic_return=1.0, surprise_reward=0.11852133274078369
# SPS: 69
# global_step=14616, episodic_return=0.0, surprise_reward=0.081904835999012
# global_step=14664, episodic_return=0.0, surprise_reward=0.11058946698904037
# global_step=14672, episodic_return=1.0, surprise_reward=0.11888279020786285
# global_step=15040, episodic_return=0.0, surprise_reward=0.13578687608242035
# global_step=15080, episodic_return=0.0, surprise_reward=0.11000651121139526
# global_step=15224, episodic_return=0.0, surprise_reward=0.09485767781734467
# global_step=15232, episodic_return=2.0, surprise_reward=0.11964504420757294
# global_step=15312, episodic_return=2.0, surprise_reward=0.1203760951757431
# SPS: 73
# global_step=15672, episodic_return=0.0, surprise_reward=0.08503757417201996
# global_step=15896, episodic_return=1.0, surprise_reward=0.10943429172039032
# global_step=16008, episodic_return=1.0, surprise_reward=0.09877662360668182
# global_step=16152, episodic_return=0.0, surprise_reward=0.09066055715084076
# global_step=16288, episodic_return=0.0, surprise_reward=0.13187748193740845
# SPS: 77
# global_step=16520, episodic_return=2.0, surprise_reward=0.12651294469833374
# global_step=16784, episodic_return=1.0, surprise_reward=0.11977475136518478
# global_step=16816, episodic_return=2.0, surprise_reward=0.11708870530128479
# global_step=17120, episodic_return=1.0, surprise_reward=0.12550079822540283
# global_step=17192, episodic_return=1.0, surprise_reward=0.10971008986234665
# global_step=17192, episodic_return=2.0, surprise_reward=0.10971008986234665
# global_step=17216, episodic_return=0.0, surprise_reward=0.16452249884605408
# SPS: 80
# global_step=17696, episodic_return=1.0, surprise_reward=0.12974970042705536
# global_step=17768, episodic_return=1.0, surprise_reward=0.09430268406867981
# global_step=18048, episodic_return=1.0, surprise_reward=0.14830029010772705
# global_step=18200, episodic_return=1.0, surprise_reward=0.16346894204616547
# global_step=18232, episodic_return=0.0, surprise_reward=0.12527506053447723
# SPS: 84
# global_step=18704, episodic_return=2.0, surprise_reward=0.12908205389976501
# global_step=19168, episodic_return=3.0, surprise_reward=0.14491760730743408
# global_step=19264, episodic_return=0.0, surprise_reward=0.09735164046287537
# global_step=19296, episodic_return=0.0, surprise_reward=0.09591500461101532
# global_step=19328, episodic_return=4.0, surprise_reward=0.09839336574077606
# SPS: 87
# global_step=19552, episodic_return=1.0, surprise_reward=0.07714386284351349
# global_step=19576, episodic_return=3.0, surprise_reward=0.11962457001209259
# global_step=19896, episodic_return=3.0, surprise_reward=0.07034558802843094
# global_step=20080, episodic_return=1.0, surprise_reward=0.09914487600326538
# global_step=20280, episodic_return=0.0, surprise_reward=0.14416947960853577
# SPS: 91
# global_step=20800, episodic_return=1.0, surprise_reward=0.13703876733779907
# global_step=20880, episodic_return=0.0, surprise_reward=0.12872575223445892
# global_step=20936, episodic_return=1.0, surprise_reward=0.13947446644306183
# global_step=20976, episodic_return=3.0, surprise_reward=0.11996187269687653
# global_step=21016, episodic_return=3.0, surprise_reward=0.12963290512561798
# global_step=21152, episodic_return=3.0, surprise_reward=0.11468538641929626
# global_step=21240, episodic_return=0.0, surprise_reward=0.09368471801280975
# SPS: 94
# global_step=21920, episodic_return=0.0, surprise_reward=0.0862799659371376
# global_step=21976, episodic_return=0.0, surprise_reward=0.17006656527519226
# global_step=22080, episodic_return=3.0, surprise_reward=0.10484573990106583
# global_step=22328, episodic_return=1.0, surprise_reward=0.1069907695055008
# global_step=22392, episodic_return=1.0, surprise_reward=0.1278841346502304
# global_step=22424, episodic_return=2.0, surprise_reward=0.1664046347141266
# global_step=22528, episodic_return=1.0, surprise_reward=0.13519462943077087
# SPS: 97
# global_step=22864, episodic_return=2.0, surprise_reward=0.13651525974273682
# global_step=23136, episodic_return=1.0, surprise_reward=0.0930662602186203
# global_step=23256, episodic_return=1.0, surprise_reward=0.13600343465805054
# global_step=23528, episodic_return=0.0, surprise_reward=0.16135334968566895
# SPS: 99
# global_step=23576, episodic_return=1.0, surprise_reward=0.11479810625314713
# global_step=24088, episodic_return=2.0, surprise_reward=0.11182258278131485
# global_step=24184, episodic_return=0.0, surprise_reward=0.11335135251283646
# global_step=24320, episodic_return=0.0, surprise_reward=0.14075641334056854
# global_step=24576, episodic_return=3.0, surprise_reward=0.10661516338586807
# SPS: 102
# global_step=24616, episodic_return=0.0, surprise_reward=0.18339903652668
# global_step=24632, episodic_return=4.0, surprise_reward=0.1309182345867157
# global_step=24688, episodic_return=2.0, surprise_reward=0.07696197926998138
# global_step=25136, episodic_return=2.0, surprise_reward=0.09254111349582672
# global_step=25152, episodic_return=0.0, surprise_reward=0.0797029584646225
# global_step=25448, episodic_return=1.0, surprise_reward=0.09092488884925842
# SPS: 105
# global_step=25608, episodic_return=0.0, surprise_reward=0.07074613124132156
# global_step=25632, episodic_return=0.0, surprise_reward=0.14612475037574768
# global_step=25952, episodic_return=1.0, surprise_reward=0.16284066438674927
# global_step=26000, episodic_return=1.0, surprise_reward=0.1483185589313507
# global_step=26160, episodic_return=0.0, surprise_reward=0.09710876643657684
# global_step=26536, episodic_return=1.0, surprise_reward=0.15739688277244568
# global_step=26568, episodic_return=3.0, surprise_reward=0.12267115712165833
# SPS: 107
# global_step=26968, episodic_return=0.0, surprise_reward=0.10868244618177414
# global_step=27016, episodic_return=0.0, surprise_reward=0.13462387025356293
# global_step=27432, episodic_return=3.0, surprise_reward=0.16046351194381714
# SPS: 110
# global_step=27760, episodic_return=3.0, surprise_reward=0.1670154631137848
# global_step=27808, episodic_return=4.0, surprise_reward=0.12864255905151367
# global_step=27816, episodic_return=2.0, surprise_reward=0.11106239259243011
# global_step=28152, episodic_return=2.0, surprise_reward=0.14843302965164185
# global_step=28288, episodic_return=3.0, surprise_reward=0.12086889892816544
# global_step=28296, episodic_return=1.0, surprise_reward=0.146747887134552
# SPS: 113
# global_step=28704, episodic_return=1.0, surprise_reward=0.07057718932628632
# global_step=28832, episodic_return=2.0, surprise_reward=0.06940045952796936
# global_step=28936, episodic_return=1.0, surprise_reward=0.10920953750610352
# global_step=29088, episodic_return=1.0, surprise_reward=0.11849034577608109
# global_step=29632, episodic_return=1.0, surprise_reward=0.0967295914888382
# SPS: 115
# global_step=29752, episodic_return=3.0, surprise_reward=0.100271075963974
# global_step=29952, episodic_return=1.0, surprise_reward=0.12074215710163116
# global_step=30056, episodic_return=2.0, surprise_reward=0.1115659773349762
# global_step=30312, episodic_return=3.0, surprise_reward=0.14697027206420898
# global_step=30688, episodic_return=2.0, surprise_reward=0.06371872127056122
# SPS: 118
# global_step=30992, episodic_return=0.0, surprise_reward=0.08851337432861328
# global_step=31136, episodic_return=1.0, surprise_reward=0.12762555480003357
# global_step=31320, episodic_return=1.0, surprise_reward=0.07682141661643982
# global_step=31392, episodic_return=4.0, surprise_reward=0.1034172847867012
# global_step=31512, episodic_return=5.0, surprise_reward=0.07461383193731308
# global_step=31712, episodic_return=0.0, surprise_reward=0.06286820769309998
# global_step=31744, episodic_return=1.0, surprise_reward=0.07112263143062592
# SPS: 120
# global_step=31824, episodic_return=3.0, surprise_reward=0.09379281103610992
# global_step=32040, episodic_return=0.0, surprise_reward=0.09428086876869202
# global_step=32328, episodic_return=0.0, surprise_reward=0.10677452385425568
# global_step=32768, episodic_return=1.0, surprise_reward=0.11094576120376587
# SPS: 122
# global_step=32872, episodic_return=1.0, surprise_reward=0.09059120714664459
# global_step=32880, episodic_return=3.0, surprise_reward=0.12329722195863724
# global_step=32960, episodic_return=1.0, surprise_reward=0.07076136767864227
# global_step=33040, episodic_return=0.0, surprise_reward=0.16731205582618713
# global_step=33640, episodic_return=2.0, surprise_reward=0.1214953064918518
# SPS: 125
# global_step=33960, episodic_return=0.0, surprise_reward=0.1381470263004303
# global_step=34008, episodic_return=0.0, surprise_reward=0.10687855631113052
# global_step=34056, episodic_return=3.0, surprise_reward=0.13651502132415771
# global_step=34288, episodic_return=1.0, surprise_reward=0.060921281576156616
# global_step=34320, episodic_return=1.0, surprise_reward=0.08623605966567993
# global_step=34488, episodic_return=5.0, surprise_reward=0.1429521143436432
# global_step=34704, episodic_return=0.0, surprise_reward=0.11045381426811218
# global_step=34808, episodic_return=2.0, surprise_reward=0.08658114820718765
# SPS: 127
# global_step=35088, episodic_return=0.0, surprise_reward=0.13012650609016418
# global_step=35288, episodic_return=0.0, surprise_reward=0.08229051530361176
# global_step=35424, episodic_return=0.0, surprise_reward=0.10416310280561447
# global_step=35480, episodic_return=1.0, surprise_reward=0.10388697683811188
# global_step=35488, episodic_return=0.0, surprise_reward=0.13120901584625244
# SPS: 129
# global_step=36216, episodic_return=3.0, surprise_reward=0.08032503724098206
# global_step=36264, episodic_return=0.0, surprise_reward=0.11828966438770294
# global_step=36344, episodic_return=2.0, surprise_reward=0.1093510091304779
# global_step=36416, episodic_return=0.0, surprise_reward=0.08019363880157471
# global_step=36496, episodic_return=0.0, surprise_reward=0.07725817710161209
# global_step=36760, episodic_return=3.0, surprise_reward=0.10468151420354843
# global_step=36848, episodic_return=2.0, surprise_reward=0.06833334267139435
# SPS: 132
# global_step=37528, episodic_return=0.0, surprise_reward=0.09840711951255798
# global_step=37656, episodic_return=4.0, surprise_reward=0.11760365217924118
# global_step=37656, episodic_return=1.0, surprise_reward=0.11760365217924118
# global_step=37712, episodic_return=1.0, surprise_reward=0.139252170920372
# global_step=37816, episodic_return=0.0, surprise_reward=0.14488250017166138
# SPS: 134
# global_step=38216, episodic_return=1.0, surprise_reward=0.08130500465631485
# global_step=38584, episodic_return=3.0, surprise_reward=0.10533457249403
# global_step=38736, episodic_return=0.0, surprise_reward=0.10897835344076157
# global_step=38744, episodic_return=0.0, surprise_reward=0.08600661158561707
# SPS: 136
# global_step=38960, episodic_return=3.0, surprise_reward=0.08582109957933426
# global_step=39568, episodic_return=1.0, surprise_reward=0.1479509174823761
# global_step=39584, episodic_return=0.0, surprise_reward=0.1586478352546692
# global_step=39704, episodic_return=3.0, surprise_reward=0.1250976026058197
# global_step=39720, episodic_return=2.0, surprise_reward=0.15512505173683167
# SPS: 138
# global_step=39968, episodic_return=0.0, surprise_reward=0.11583858728408813
# global_step=40168, episodic_return=1.0, surprise_reward=0.0807790756225586
# global_step=40176, episodic_return=4.0, surprise_reward=0.11018584668636322
# global_step=40504, episodic_return=2.0, surprise_reward=0.0991205945611
# global_step=40904, episodic_return=0.0, surprise_reward=0.10733029246330261
# SPS: 140
# global_step=40968, episodic_return=0.0, surprise_reward=0.11386504024267197
# global_step=40976, episodic_return=1.0, surprise_reward=0.1513725072145462
# global_step=40992, episodic_return=1.0, surprise_reward=0.1787075400352478
# global_step=41504, episodic_return=1.0, surprise_reward=0.1171889454126358
# global_step=41568, episodic_return=1.0, surprise_reward=0.13632327318191528
# global_step=41928, episodic_return=1.0, surprise_reward=0.09655041992664337
# global_step=41936, episodic_return=0.0, surprise_reward=0.11389118432998657
# SPS: 142
# global_step=42128, episodic_return=0.0, surprise_reward=0.09249545633792877
# global_step=42176, episodic_return=0.0, surprise_reward=0.11579661816358566
# global_step=42192, episodic_return=5.0, surprise_reward=0.13582998514175415
# global_step=42536, episodic_return=2.0, surprise_reward=0.1610621213912964
# SPS: 143
# global_step=43032, episodic_return=0.0, surprise_reward=0.12001626938581467
# global_step=43440, episodic_return=3.0, surprise_reward=0.12693147361278534
# global_step=43440, episodic_return=1.0, surprise_reward=0.12693147361278534
# global_step=43536, episodic_return=2.0, surprise_reward=0.06574408710002899
# global_step=43640, episodic_return=3.0, surprise_reward=0.08417428284883499
# SPS: 145
# global_step=44144, episodic_return=2.0, surprise_reward=0.10644713044166565
# global_step=44288, episodic_return=1.0, surprise_reward=0.09731745719909668
# global_step=44360, episodic_return=3.0, surprise_reward=0.08672212809324265
# global_step=44480, episodic_return=0.0, surprise_reward=0.11079920828342438
# global_step=44784, episodic_return=5.0, surprise_reward=0.11198382824659348
# SPS: 147
# global_step=45184, episodic_return=2.0, surprise_reward=0.11139823496341705
# global_step=45192, episodic_return=1.0, surprise_reward=0.15857379138469696
# global_step=45208, episodic_return=0.0, surprise_reward=0.2076997309923172
# global_step=45288, episodic_return=2.0, surprise_reward=0.1602388173341751
# global_step=45376, episodic_return=0.0, surprise_reward=0.12936030328273773
# global_step=45520, episodic_return=0.0, surprise_reward=0.11791230738162994
# global_step=45816, episodic_return=1.0, surprise_reward=0.07147572934627533
# SPS: 149
# global_step=46216, episodic_return=0.0, surprise_reward=0.09142061322927475
# global_step=46400, episodic_return=1.0, surprise_reward=0.06785250455141068
# global_step=46456, episodic_return=0.0, surprise_reward=0.1653912365436554
# global_step=46504, episodic_return=0.0, surprise_reward=0.1106264740228653
# global_step=46696, episodic_return=0.0, surprise_reward=0.07477866858243942
# global_step=47000, episodic_return=3.0, surprise_reward=0.07463334500789642
# SPS: 151
# global_step=47272, episodic_return=0.0, surprise_reward=0.17370854318141937
# global_step=47912, episodic_return=1.0, surprise_reward=0.14751116931438446
# global_step=48024, episodic_return=3.0, surprise_reward=0.18091504275798798
# global_step=48080, episodic_return=2.0, surprise_reward=0.2350531816482544
# SPS: 152
# global_step=48232, episodic_return=0.0, surprise_reward=0.1039014607667923
# global_step=48360, episodic_return=5.0, surprise_reward=0.14821591973304749
# global_step=48520, episodic_return=2.0, surprise_reward=0.10179279744625092
# global_step=48560, episodic_return=3.0, surprise_reward=0.14884638786315918
# global_step=48896, episodic_return=2.0, surprise_reward=0.2015184611082077
# SPS: 154
# global_step=49320, episodic_return=1.0, surprise_reward=0.12241548299789429
# global_step=49360, episodic_return=0.0, surprise_reward=0.19703635573387146
# global_step=49456, episodic_return=1.0, surprise_reward=0.18783125281333923
# global_step=49456, episodic_return=1.0, surprise_reward=0.18783125281333923
# global_step=49680, episodic_return=0.0, surprise_reward=0.1810402274131775
# global_step=49808, episodic_return=1.0, surprise_reward=0.12662003934383392
# global_step=50176, episodic_return=1.0, surprise_reward=0.24177053570747375
# SPS: 156
# global_step=50736, episodic_return=0.0, surprise_reward=0.20854777097702026
# global_step=50760, episodic_return=4.0, surprise_reward=0.1349339485168457
# global_step=50784, episodic_return=1.0, surprise_reward=0.12653174996376038
# global_step=50832, episodic_return=1.0, surprise_reward=0.23669682443141937
# global_step=51032, episodic_return=1.0, surprise_reward=0.0846303403377533
# SPS: 157
# global_step=51448, episodic_return=3.0, surprise_reward=0.15580762922763824
# global_step=51480, episodic_return=1.0, surprise_reward=0.11165744066238403
# SPS: 159
# global_step=52312, episodic_return=1.0, surprise_reward=0.16926074028015137
# global_step=52464, episodic_return=2.0, surprise_reward=0.2894653081893921
# global_step=52512, episodic_return=2.0, surprise_reward=0.16290731728076935
# global_step=52520, episodic_return=1.0, surprise_reward=0.13806530833244324
# global_step=52560, episodic_return=2.0, surprise_reward=0.13011044263839722
# global_step=52600, episodic_return=2.0, surprise_reward=0.1647321581840515
# global_step=52824, episodic_return=1.0, surprise_reward=0.1641455441713333
# SPS: 161
# global_step=53368, episodic_return=0.0, surprise_reward=0.2108553946018219
# global_step=53600, episodic_return=6.0, surprise_reward=0.17060133814811707
# global_step=53648, episodic_return=0.0, surprise_reward=0.30835893750190735
# global_step=53776, episodic_return=1.0, surprise_reward=0.1664719134569168
# global_step=53800, episodic_return=0.0, surprise_reward=0.1254092901945114
# SPS: 162
# global_step=54520, episodic_return=3.0, surprise_reward=0.1648561656475067
# global_step=54816, episodic_return=3.0, surprise_reward=0.2603403329849243
# global_step=54840, episodic_return=0.0, surprise_reward=0.20640511810779572
# global_step=54880, episodic_return=0.0, surprise_reward=0.2267293930053711
# global_step=54944, episodic_return=4.0, surprise_reward=0.16785873472690582
# SPS: 164
# global_step=55328, episodic_return=1.0, surprise_reward=0.19214028120040894
# global_step=55608, episodic_return=3.0, surprise_reward=0.20046979188919067
# global_step=55920, episodic_return=1.0, surprise_reward=0.24514082074165344
# global_step=56072, episodic_return=1.0, surprise_reward=0.14666429162025452
# global_step=56256, episodic_return=5.0, surprise_reward=0.0981207937002182
# global_step=56264, episodic_return=1.0, surprise_reward=0.13612821698188782
# global_step=56280, episodic_return=1.0, surprise_reward=0.1476670503616333
# global_step=56312, episodic_return=1.0, surprise_reward=0.11861877143383026
# SPS: 164
# global_step=56704, episodic_return=1.0, surprise_reward=0.1908828467130661
# global_step=57304, episodic_return=0.0, surprise_reward=0.10283619165420532
# global_step=57320, episodic_return=0.0, surprise_reward=0.1074509546160698
# SPS: 165
# global_step=57360, episodic_return=1.0, surprise_reward=0.2589074969291687
# global_step=57536, episodic_return=1.0, surprise_reward=0.2379111647605896
# global_step=57800, episodic_return=3.0, surprise_reward=0.20559874176979065
# global_step=57864, episodic_return=2.0, surprise_reward=0.1840701848268509
# global_step=58320, episodic_return=0.0, surprise_reward=0.2771902084350586
# global_step=58368, episodic_return=2.0, surprise_reward=0.15739783644676208
# SPS: 165
# global_step=58544, episodic_return=1.0, surprise_reward=0.2667548358440399
# global_step=58544, episodic_return=3.0, surprise_reward=0.2667548358440399
# global_step=58592, episodic_return=1.0, surprise_reward=0.22130374610424042
# global_step=59264, episodic_return=1.0, surprise_reward=0.13478267192840576
# global_step=59304, episodic_return=0.0, surprise_reward=0.1475784182548523
# SPS: 166
# global_step=59544, episodic_return=0.0, surprise_reward=0.12932941317558289
# global_step=59816, episodic_return=4.0, surprise_reward=0.15296241641044617
# global_step=59936, episodic_return=1.0, surprise_reward=0.19146734476089478
# global_step=60112, episodic_return=1.0, surprise_reward=0.17029345035552979
# global_step=60200, episodic_return=2.0, surprise_reward=0.2501005530357361
# global_step=60312, episodic_return=0.0, surprise_reward=0.14999492466449738
# global_step=60360, episodic_return=5.0, surprise_reward=0.20283260941505432
# SPS: 167
# global_step=60512, episodic_return=0.0, surprise_reward=0.17906758189201355
# global_step=60640, episodic_return=1.0, surprise_reward=0.23715618252754211
# SPS: 169
# global_step=61496, episodic_return=1.0, surprise_reward=0.13466766476631165
# global_step=61504, episodic_return=0.0, surprise_reward=0.20534589886665344
# global_step=61856, episodic_return=1.0, surprise_reward=0.31906601786613464
# global_step=61864, episodic_return=1.0, surprise_reward=0.2476331889629364
# global_step=61984, episodic_return=2.0, surprise_reward=0.281567245721817
# global_step=62048, episodic_return=2.0, surprise_reward=0.13043004274368286
# SPS: 170
# global_step=62520, episodic_return=3.0, surprise_reward=0.24007484316825867
# global_step=62544, episodic_return=2.0, surprise_reward=0.37565192580223083
# global_step=62880, episodic_return=0.0, surprise_reward=0.2767394781112671
# global_step=62880, episodic_return=1.0, surprise_reward=0.2767394781112671
# global_step=62984, episodic_return=0.0, surprise_reward=0.3776167631149292
# global_step=63408, episodic_return=1.0, surprise_reward=0.2817038893699646
# global_step=63424, episodic_return=1.0, surprise_reward=0.31483668088912964
# SPS: 171
# global_step=63912, episodic_return=0.0, surprise_reward=0.27627724409103394
# global_step=64488, episodic_return=5.0, surprise_reward=0.4014752507209778
# SPS: 172
# global_step=64704, episodic_return=0.0, surprise_reward=0.19337743520736694
# global_step=65024, episodic_return=3.0, surprise_reward=0.21915967762470245
# global_step=65064, episodic_return=3.0, surprise_reward=0.24113933742046356
# global_step=65096, episodic_return=3.0, surprise_reward=0.3362498879432678
# global_step=65256, episodic_return=5.0, surprise_reward=0.35414284467697144
# global_step=65400, episodic_return=2.0, surprise_reward=0.2741875946521759
# SPS: 173
# global_step=66080, episodic_return=3.0, surprise_reward=0.3136017918586731
# global_step=66216, episodic_return=3.0, surprise_reward=0.4201291501522064
# global_step=66472, episodic_return=1.0, surprise_reward=0.14688099920749664
# SPS: 174
# global_step=66632, episodic_return=1.0, surprise_reward=0.16569435596466064
# global_step=66688, episodic_return=3.0, surprise_reward=0.3048994243144989
# global_step=67048, episodic_return=2.0, surprise_reward=0.12847517430782318
# global_step=67056, episodic_return=2.0, surprise_reward=0.19493567943572998
# global_step=67520, episodic_return=3.0, surprise_reward=0.17144954204559326
# global_step=67536, episodic_return=1.0, surprise_reward=0.22773611545562744
# SPS: 175
# global_step=67792, episodic_return=2.0, surprise_reward=0.3226125240325928
# global_step=68176, episodic_return=1.0, surprise_reward=0.2394731491804123
# global_step=68536, episodic_return=0.0, surprise_reward=0.20933188498020172
# global_step=68608, episodic_return=3.0, surprise_reward=0.2717718482017517
# SPS: 177
# global_step=69056, episodic_return=3.0, surprise_reward=0.2277236133813858
# global_step=69288, episodic_return=0.0, surprise_reward=0.20975631475448608
# SPS: 178
# global_step=69656, episodic_return=3.0, surprise_reward=0.2419409602880478
# global_step=69800, episodic_return=2.0, surprise_reward=0.14730204641819
# SPS: 191
# global_step=89104, episodic_return=0.0, surprise_reward=0.14820247888565063
# global_step=89392, episodic_return=3.0, surprise_reward=0.4780162572860718
# global_step=89424, episodic_return=4.0, surprise_reward=0.4371876120567322
# global_step=89600, episodic_return=1.0, surprise_reward=0.4461386501789093
# global_step=89744, episodic_return=1.0, surprise_reward=0.20522461831569672
# global_step=89864, episodic_return=2.0, surprise_reward=0.13121159374713898
# global_step=90000, episodic_return=2.0, surprise_reward=0.2579684257507324
# SPS: 192
# SPS: 193
# global_step=91248, episodic_return=5.0, surprise_reward=0.33817023038864136
# global_step=91304, episodic_return=1.0, surprise_reward=0.4870830178260803
# global_step=91392, episodic_return=1.0, surprise_reward=0.4393150210380554
# global_step=91672, episodic_return=1.0, surprise_reward=0.3086385130882263
# global_step=91792, episodic_return=2.0, surprise_reward=0.49155643582344055
# global_step=92040, episodic_return=4.0, surprise_reward=0.415754497051239
# global_step=92072, episodic_return=4.0, surprise_reward=0.336568146944046
# SPS: 194
# global_step=92376, episodic_return=2.0, surprise_reward=0.20633159577846527
# global_step=92912, episodic_return=2.0, surprise_reward=0.5861481428146362
# SPS: 195
# global_step=93608, episodic_return=1.0, surprise_reward=0.2817223370075226
# global_step=93648, episodic_return=1.0, surprise_reward=0.35658377408981323
# global_step=93664, episodic_return=1.0, surprise_reward=0.4511633515357971
# global_step=94160, episodic_return=3.0, surprise_reward=0.41185805201530457
# SPS: 195
# global_step=94400, episodic_return=3.0, surprise_reward=0.35455816984176636
# global_step=94584, episodic_return=1.0, surprise_reward=0.5859677195549011
# global_step=94632, episodic_return=0.0, surprise_reward=0.4280640780925751
# SPS: 196
# global_step=95472, episodic_return=0.0, surprise_reward=0.22892294824123383
# global_step=95648, episodic_return=3.0, surprise_reward=0.4276615381240845
# global_step=95736, episodic_return=4.0, surprise_reward=0.23644763231277466
# global_step=96080, episodic_return=1.0, surprise_reward=0.28230053186416626
# global_step=96216, episodic_return=4.0, surprise_reward=0.38551223278045654
# SPS: 197
# global_step=96600, episodic_return=2.0, surprise_reward=0.6313853859901428
# global_step=96608, episodic_return=5.0, surprise_reward=0.49991875886917114
# global_step=97104, episodic_return=0.0, surprise_reward=0.2580617666244507
# SPS: 197
# global_step=97480, episodic_return=2.0, surprise_reward=0.13750171661376953
# global_step=97528, episodic_return=1.0, surprise_reward=0.4991148114204407
# global_step=97616, episodic_return=0.0, surprise_reward=0.2137320339679718
# global_step=97664, episodic_return=3.0, surprise_reward=0.36099711060523987
# global_step=97792, episodic_return=0.0, surprise_reward=0.5628359913825989
# global_step=97976, episodic_return=1.0, surprise_reward=0.16624224185943604
# global_step=98040, episodic_return=0.0, surprise_reward=0.4579088091850281
# SPS: 198
# global_step=99120, episodic_return=1.0, surprise_reward=0.304816335439682
# global_step=99264, episodic_return=0.0, surprise_reward=0.3703881502151489
# global_step=99272, episodic_return=0.0, surprise_reward=0.3559211492538452
# SPS: 199
# global_step=99424, episodic_return=2.0, surprise_reward=0.27401524782180786
# global_step=99656, episodic_return=2.0, surprise_reward=0.2779058516025543
# global_step=99920, episodic_return=2.0, surprise_reward=0.5462108850479126
# global_step=100032, episodic_return=0.0, surprise_reward=0.39920783042907715
# global_step=100152, episodic_return=0.0, surprise_reward=0.41896677017211914
# SPS: 200
# global_step=100656, episodic_return=0.0, surprise_reward=0.414157509803772
# global_step=101016, episodic_return=2.0, surprise_reward=0.3662850260734558
# SPS: 200
# global_step=101480, episodic_return=2.0, surprise_reward=0.4378916025161743
# global_step=101528, episodic_return=1.0, surprise_reward=0.6286652684211731
# global_step=101536, episodic_return=2.0, surprise_reward=0.520359456539154
# global_step=102128, episodic_return=3.0, surprise_reward=0.35635650157928467
# SPS: 201
# global_step=102552, episodic_return=1.0, surprise_reward=0.2755911350250244
# global_step=102568, episodic_return=2.0, surprise_reward=0.16181537508964539
# global_step=103128, episodic_return=1.0, surprise_reward=0.303276926279068
# global_step=103232, episodic_return=2.0, surprise_reward=0.5192939043045044
# SPS: 202
# global_step=103904, episodic_return=0.0, surprise_reward=0.4089660048484802
# global_step=104088, episodic_return=1.0, surprise_reward=0.4706634283065796
# global_step=104272, episodic_return=2.0, surprise_reward=0.40549585223197937
# global_step=104320, episodic_return=2.0, surprise_reward=0.2770118713378906
# SPS: 203
# global_step=105376, episodic_return=0.0, surprise_reward=0.29419785737991333
# SPS: 203
# global_step=105552, episodic_return=0.0, surprise_reward=0.5932478904724121
# global_step=105664, episodic_return=2.0, surprise_reward=0.534503698348999
# global_step=105784, episodic_return=5.0, surprise_reward=0.4736771285533905
# global_step=105944, episodic_return=2.0, surprise_reward=0.3210761547088623
# global_step=106160, episodic_return=1.0, surprise_reward=0.5272074937820435
# SPS: 204
# global_step=107040, episodic_return=5.0, surprise_reward=0.3023817539215088
# global_step=107128, episodic_return=0.0, surprise_reward=0.18356376886367798
# SPS: 205
# global_step=107712, episodic_return=0.0, surprise_reward=0.5108429193496704
# global_step=108208, episodic_return=1.0, surprise_reward=0.254550576210022
# SPS: 205
# global_step=108744, episodic_return=1.0, surprise_reward=0.3199172019958496
# global_step=108880, episodic_return=5.0, surprise_reward=0.21726489067077637
# global_step=108960, episodic_return=1.0, surprise_reward=0.2710665464401245
# global_step=109088, episodic_return=1.0, surprise_reward=0.13884519040584564
# global_step=109096, episodic_return=2.0, surprise_reward=0.2511986792087555
# global_step=109224, episodic_return=2.0, surprise_reward=0.2829594612121582
# SPS: 205
# global_step=110472, episodic_return=1.0, surprise_reward=0.3536544740200043
# global_step=110504, episodic_return=2.0, surprise_reward=0.5687643885612488
# SPS: 205
# global_step=110688, episodic_return=3.0, surprise_reward=0.28376853466033936
# global_step=110896, episodic_return=0.0, surprise_reward=0.24733716249465942
# global_step=110928, episodic_return=6.0, surprise_reward=0.16573204100131989
# global_step=111440, episodic_return=2.0, surprise_reward=0.1196470558643341
# SPS: 205
# global_step=111736, episodic_return=1.0, surprise_reward=0.2947658896446228
# global_step=111768, episodic_return=3.0, surprise_reward=0.3657410144805908
# SPS: 205
# global_step=113144, episodic_return=1.0, surprise_reward=0.36964014172554016
# SPS: 205
# SPS: 206
# global_step=115496, episodic_return=2.0, surprise_reward=0.2707238495349884
# SPS: 206
# global_step=116536, episodic_return=2.0, surprise_reward=0.6474648714065552
# SPS: 207
# global_step=116864, episodic_return=0.0, surprise_reward=0.23721376061439514
# global_step=116888, episodic_return=1.0, surprise_reward=0.5237776041030884
# SPS: 207
# global_step=118080, episodic_return=1.0, surprise_reward=0.24044722318649292
# global_step=118360, episodic_return=0.0, surprise_reward=0.2885088324546814
# SPS: 207
# global_step=119144, episodic_return=8.0, surprise_reward=0.45277664065361023
# global_step=119160, episodic_return=0.0, surprise_reward=0.3712385892868042
# global_step=119752, episodic_return=3.0, surprise_reward=0.5670469999313354
# SPS: 208
# global_step=120232, episodic_return=4.0, surprise_reward=0.2796793580055237
# global_step=120744, episodic_return=2.0, surprise_reward=0.1718066930770874
# SPS: 208
# global_step=121408, episodic_return=2.0, surprise_reward=0.48569273948669434
# global_step=121448, episodic_return=2.0, surprise_reward=0.7594431042671204
# global_step=121744, episodic_return=0.0, surprise_reward=0.25044476985931396
# SPS: 209
# global_step=122488, episodic_return=0.0, surprise_reward=0.2922448515892029
# SPS: 209
# global_step=123088, episodic_return=1.0, surprise_reward=0.510006308555603
# global_step=123488, episodic_return=0.0, surprise_reward=0.2572699785232544
# SPS: 210
# global_step=124488, episodic_return=0.0, surprise_reward=0.28220415115356445
# global_step=124752, episodic_return=1.0, surprise_reward=0.20689348876476288
# SPS: 211
# global_step=125584, episodic_return=3.0, surprise_reward=0.44341057538986206
# global_step=125736, episodic_return=1.0, surprise_reward=0.4638177454471588
# SPS: 211
# global_step=126472, episodic_return=4.0, surprise_reward=0.26062560081481934
# SPS: 212
# global_step=127488, episodic_return=2.0, surprise_reward=0.3411861062049866
# global_step=127616, episodic_return=1.0, surprise_reward=0.23986832797527313
# global_step=127808, episodic_return=2.0, surprise_reward=0.334035724401474
# SPS: 213
# global_step=128872, episodic_return=1.0, surprise_reward=0.42230698466300964
# SPS: 213
# global_step=129840, episodic_return=3.0, surprise_reward=0.3247915208339691
# SPS: 213
# global_step=130312, episodic_return=2.0, surprise_reward=0.19073191285133362
# global_step=130808, episodic_return=1.0, surprise_reward=0.3459679186344147
# SPS: 214
# global_step=131232, episodic_return=1.0, surprise_reward=0.1898282766342163
# global_step=131504, episodic_return=3.0, surprise_reward=0.25438350439071655
# global_step=131792, episodic_return=1.0, surprise_reward=0.4204201102256775
# SPS: 214
# global_step=132136, episodic_return=4.0, surprise_reward=0.2738824188709259
# global_step=132408, episodic_return=0.0, surprise_reward=0.2881074547767639
# global_step=132672, episodic_return=0.0, surprise_reward=0.2972613275051117
# global_step=132808, episodic_return=0.0, surprise_reward=0.4439520835876465
# global_step=132976, episodic_return=1.0, surprise_reward=0.3392617404460907
# SPS: 215
# global_step=133520, episodic_return=1.0, surprise_reward=0.3009149432182312
# global_step=133976, episodic_return=1.0, surprise_reward=0.23185329139232635
# SPS: 215
# global_step=134752, episodic_return=1.0, surprise_reward=0.3566359877586365
# global_step=134840, episodic_return=3.0, surprise_reward=0.3187497854232788
# global_step=134888, episodic_return=3.0, surprise_reward=0.2089022994041443
# SPS: 216
# global_step=135320, episodic_return=1.0, surprise_reward=0.1427992284297943
# SPS: 216
# global_step=137096, episodic_return=0.0, surprise_reward=0.292213499546051
# global_step=137112, episodic_return=1.0, surprise_reward=0.1893758326768875
# SPS: 217
# global_step=137600, episodic_return=1.0, surprise_reward=0.3020271062850952
# SPS: 217
# global_step=138328, episodic_return=1.0, surprise_reward=0.2255367934703827
# global_step=138600, episodic_return=0.0, surprise_reward=0.2005361020565033
# SPS: 218
# global_step=140200, episodic_return=3.0, surprise_reward=0.3000969886779785
# SPS: 218
# global_step=141136, episodic_return=0.0, surprise_reward=0.30338647961616516
# global_step=141184, episodic_return=1.0, surprise_reward=0.22602753341197968
# SPS: 219
# global_step=141576, episodic_return=2.0, surprise_reward=0.32013362646102905
# SPS: 219
# global_step=143016, episodic_return=0.0, surprise_reward=0.28577664494514465
# SPS: 220
# global_step=143816, episodic_return=1.0, surprise_reward=0.29903191328048706
# SPS: 221
# global_step=144608, episodic_return=2.0, surprise_reward=0.19132918119430542
# global_step=144680, episodic_return=1.0, surprise_reward=0.21573960781097412
# global_step=144704, episodic_return=3.0, surprise_reward=0.23656362295150757
# global_step=144976, episodic_return=0.0, surprise_reward=0.31462204456329346
# SPS: 221
# global_step=145592, episodic_return=0.0, surprise_reward=0.267902672290802
# SPS: 222
# global_step=146560, episodic_return=2.0, surprise_reward=0.14889100193977356
# global_step=146984, episodic_return=0.0, surprise_reward=0.11762548983097076
# SPS: 222
# global_step=147920, episodic_return=0.0, surprise_reward=0.311271607875824
# global_step=148440, episodic_return=6.0, surprise_reward=0.30020642280578613
# SPS: 223
# global_step=148504, episodic_return=2.0, surprise_reward=0.37438273429870605
# global_step=148536, episodic_return=0.0, surprise_reward=0.36162689328193665
# global_step=148712, episodic_return=0.0, surprise_reward=0.25829988718032837
# SPS: 223
# global_step=149936, episodic_return=1.0, surprise_reward=0.38775986433029175
# global_step=150504, episodic_return=1.0, surprise_reward=0.452068954706192
# SPS: 224
# global_step=151376, episodic_return=0.0, surprise_reward=0.15040317177772522
# global_step=151416, episodic_return=0.0, surprise_reward=0.27429574728012085
# SPS: 224
# global_step=152048, episodic_return=1.0, surprise_reward=0.15417265892028809
# SPS: 225
# global_step=152904, episodic_return=2.0, surprise_reward=0.3827071785926819
# global_step=153232, episodic_return=3.0, surprise_reward=0.204843670129776
# global_step=153280, episodic_return=1.0, surprise_reward=0.1219339668750763
# SPS: 225
# ...
# global_step=1711432, episodic_return=11.0, surprise_reward=0.1547912061214447
# global_step=1711496, episodic_return=4.0, surprise_reward=0.1703961193561554
# global_step=1711920, episodic_return=7.0, surprise_reward=0.060442809015512466
# SPS: 448
# global_step=1712368, episodic_return=22.0, surprise_reward=0.14438371360301971
# global_step=1712824, episodic_return=6.0, surprise_reward=0.06600436568260193
# global_step=1713056, episodic_return=5.0, surprise_reward=0.10051015019416809
# SPS: 448
# global_step=1713272, episodic_return=7.0, surprise_reward=0.17160184681415558
# SPS: 452
# global_step=1800296, episodic_return=10.0, surprise_reward=0.12664037942886353
# SPS: 452
# global_step=1801888, episodic_return=18.0, surprise_reward=0.17553724348545074
# SPS: 452
# global_step=1802576, episodic_return=11.0, surprise_reward=0.17764955759048462
# global_step=1802768, episodic_return=10.0, surprise_reward=0.11763463169336319
# global_step=1802872, episodic_return=15.0, surprise_reward=0.19371618330478668
# global_step=1803128, episodic_return=7.0, surprise_reward=0.15469974279403687
# SPS: 452
# global_step=1803824, episodic_return=8.0, surprise_reward=0.10678665339946747
# global_step=1804056, episodic_return=13.0, surprise_reward=0.17768079042434692
# SPS: 452
# global_step=1805032, episodic_return=12.0, surprise_reward=0.05531768500804901
# SPS: 452
# SPS: 452
# global_step=1807096, episodic_return=16.0, surprise_reward=0.1220608800649643
# global_step=1807200, episodic_return=10.0, surprise_reward=0.2330569475889206
# SPS: 452
# global_step=1807504, episodic_return=16.0, surprise_reward=0.14400210976600647
# global_step=1807896, episodic_return=9.0, surprise_reward=0.11720532178878784
# global_step=1808216, episodic_return=11.0, surprise_reward=0.09938390552997589
# SPS: 452
# global_step=1808552, episodic_return=14.0, surprise_reward=0.1528683453798294
# SPS: 452
# global_step=1810112, episodic_return=22.0, surprise_reward=0.09738028049468994
# SPS: 452
# global_step=1810648, episodic_return=15.0, surprise_reward=0.25265902280807495
# SPS: 452
# global_step=1811520, episodic_return=11.0, surprise_reward=0.16476260125637054
# global_step=1812216, episodic_return=9.0, surprise_reward=0.0758754163980484
# global_step=1812272, episodic_return=10.0, surprise_reward=0.06625482439994812
# global_step=1812280, episodic_return=8.0, surprise_reward=0.19531670212745667
# SPS: 452
# global_step=1812632, episodic_return=20.0, surprise_reward=0.11186717450618744
# global_step=1813152, episodic_return=21.0, surprise_reward=0.16683971881866455
# SPS: 452
# global_step=1814232, episodic_return=11.0, surprise_reward=0.10033158957958221
# SPS: 452
# global_step=1814896, episodic_return=10.0, surprise_reward=0.13322825729846954
# SPS: 452
# global_step=1816224, episodic_return=7.0, surprise_reward=0.10470608621835709
# SPS: 452
# global_step=1816928, episodic_return=13.0, surprise_reward=0.07017354667186737
# global_step=1817168, episodic_return=15.0, surprise_reward=0.1390324831008911

# %%
envs.close()

# %%
torch.save(Agent, "pretrained_models/ppo_for_ICM_atari.pth")
torch.save(icm, "pretrained_models/icm_atari.pth")

# %% [markdown]
# # Results Visualization

# %%
# Extract data from results_RND
icm_global_step = results_ICM["global_step"]
icm_return_value = results_ICM["return_value"]
icm_intrinsic_reward = results_ICM["intrinsic_reward"]

df_icm = pd.DataFrame({'global_step': icm_global_step, 'return_value': icm_return_value, 'intrinsic_reward': icm_intrinsic_reward})
# Save DataFrames to CSV files
df_icm.to_csv('results_icm_atari.csv', index=False)

# %%
# Plot the data
plt.plot(rnd_global_step, rnd_return_value, label='RND')
plt.plot(ppo_global_step, ppo_return_value, label='PPO')
plt.plot(icm_global_step, icm_return_value, label='ICM')
plt.xlabel('Global Step')
plt.ylabel('Return Value')
plt.title('Return Value vs Global Step')
plt.legend()
plt.show()
